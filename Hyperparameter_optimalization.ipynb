# %% [markdown]
# # Hyperparameter optimalizations

# %% [markdown]
# Imports and Data Preparation

# %%
from numpy.random import seed
seed(1)

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from nltk.tokenize import sent_tokenize,word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import nltk
from nltk.corpus import stopwords

from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

import tensorflow as tf
from tensorflow.keras.layers import LSTM
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import StandardScaler

import pickle

nltk.download('punkt')
nltk.download('stopwords')
#np.random.seed(1)
random_state = 7
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/drive')
train = pd.read_csv('/content/drive/My Drive/Author_identification/train.csv')
test = pd.read_csv('/content/drive/My Drive/Author_identification/test.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train['sentences'] = train.text.transform(lambda x: len(sent_tokenize(x)))
train['words'] = train.text.transform(lambda x: len(word_tokenize(x)))
train['text_length'] = train.text.transform(lambda x: len(x))

text_info = train.groupby("author")[['sentences','words','text_length']].sum()
text_info
# Out:
#         sentences   words  text_length
# author
# EAP          8206  232184      1123585
# HPL          5876  173979       878178
# MWS          6128  188824       916632

# %%
stop_words = set(stopwords.words('english')).union(set([',','.','?','!',':',';',"'",'"','-',"''","`","``"]))
author_dict = {'EAP': 0, 'HPL': 1, 'MWS': 2}

# %%
new_text = []
new_author = []
for i, row in train[['text','author']].iterrows():
    word_tokens = word_tokenize(row['text'])
    new_text.append(" ".join([w for w in word_tokens if not w in stop_words]))
    new_author.append(author_dict[row['author']])
new_train = pd.DataFrame(data={'text': new_text, 'author': new_author})

# %%
new_test_text = []
for i, row in test[['text']].iterrows():
    word_tokens = word_tokenize(row['text'])
    new_test_text.append(" ".join([w for w in word_tokens if not w in stop_words]))
new_test = pd.DataFrame(data={'text': new_text})

# %%
X = new_train['text']
y = new_train['author']
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=random_state)
X_test = new_test['text']

# %%
new_text_ws = []
for i, row in train[['text']].iterrows():
    word_tokens = word_tokenize(row['text'])
    new_text_ws.append(" ".join([w for w in word_tokens if not w in [',','.','?','!',':',';',"'",'"','-',"''","`","``"]]).lower())
new_train_ws = pd.DataFrame(data={'text': new_text_ws, 'author': new_author})

# %%
X_ws = new_train_ws['text']
y_ws = new_train_ws['author']
X_ws_train, X_ws_valid, y_ws_train, y_ws_valid = train_test_split(X_ws, y_ws, test_size=0.3, random_state=random_state)

# %%
X_train_list = list(X_train)
y_train_list = list(y_train)
X_valid_list = list(X_valid)
y_valid_list = list(y_valid)

# %%
X_ws_train_list = list(X_ws_train)
y_ws_train_list = list(y_ws_train)
X_ws_valid_list = list(X_ws_valid)
y_ws_valid_list = list(y_ws_valid)

# %%
y_ws_train_list = np.array(y_ws_train_list)
y_ws_valid_list = np.array(y_ws_valid_list)

# %% [markdown]
# ### Pre-trained fastText vectors

# %%
#import gensim.downloader

# %%
#fasttext_vectors = gensim.downloader.load('fasttext-wiki-news-subwords-300')

# %%
#with open('fasttext_vectors.pickle', 'wb') as f:
#    pickle.dump(fasttext_vectors, f)

# %%
with open("/content/drive/MyDrive/Author_identification/fasttext_vectors.pickle", 'rb') as f:
    fasttext_vectors = pickle.load(f)

# %% [markdown]
# In each entry we collect the wordvectors of the tokens and take the mean of those (300 dimensional vectors).

# %%
X_ws_train_ft_mean_vectors = np.empty([len(X_ws_train_list), 300])
for j in range(len(X_ws_train_list)):
    X_ws_train_ft_vectors = np.empty([len(X_ws_train_list[j].split()), 300])
    for i in range(len(X_ws_train_list[j].split())):
        try:
            X_ws_train_ft_vectors[i] = fasttext_vectors.wv[X_ws_train_list[j].split()[i]]
        except KeyError:
            X_ws_train_ft_vectors[i] = np.zeros(300)
    X_ws_train_ft_mean_vectors[j] = np.mean(X_ws_train_ft_vectors, axis=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
scaler = StandardScaler()
X_ws_train_ft_mean_vectors = scaler.fit_transform(X_ws_train_ft_mean_vectors)

# %%
X_ws_valid_ft_mean_vectors = np.empty([len(X_ws_valid_list), 300])
for j in range(len(X_ws_valid_list)):
    X_ws_valid_ft_vectors = np.empty([len(X_ws_valid_list[j].split()), 300])
    for i in range(len(X_ws_valid_list[j].split())):
        try:
            X_ws_valid_ft_vectors[i] = fasttext_vectors.wv[X_ws_valid_list[j].split()[i]]
        except KeyError:
            X_ws_valid_ft_vectors[i] = np.zeros(300)
    X_ws_valid_ft_mean_vectors[j] = np.mean(X_ws_valid_ft_vectors, axis=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
scaler = StandardScaler()
X_ws_valid_ft_mean_vectors = scaler.fit_transform(X_ws_valid_ft_mean_vectors)

# %%
from keras.utils import to_categorical
y_ws_train_list = to_categorical(y_ws_train_list)
y_ws_valid_list = to_categorical(y_ws_valid_list)

# %% [markdown]
# ### Hyperparameter optimalization with fasttext vectors

# %%
import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.callbacks import EarlyStopping
import numpy as np

# %%
data = X_ws_train_ft_mean_vectors, y_ws_train_list, X_ws_valid_ft_mean_vectors, y_ws_valid_list

# %%
from keras.layers import GlobalMaxPooling1D, Conv1D, MaxPooling1D, Flatten, Bidirectional, SpatialDropout1D
from keras.layers.recurrent import LSTM
from keras.layers.normalization import BatchNormalization

# %%
with open('dataset1.npy', 'wb') as f:
    np.save(f, X_ws_train_ft_mean_vectors)
    np.save(f, y_ws_train_list)
    np.save(f, X_ws_valid_ft_mean_vectors)
    np.save(f, y_ws_valid_list)

with open('dataset1.npy', 'rb') as f:
    X_train = np.load(f)
    y_train = np.load(f)
    X_valid = np.load(f)
    y_valid = np.load(f)

# %%
def data():
  with open('dataset1.npy', 'rb') as f:
    x_train = np.load(f)
    y_train = np.load(f)
    x_test = np.load(f)
    y_test = np.load(f)
  
  return x_train, y_train, x_test, y_test

# %%
def create_model(x_train, y_train, x_test, y_test):
    from keras.layers import Layer
    from keras import backend as K

    class Swish(Layer):
        def __init__(self, beta, **kwargs):
            super(Swish, self).__init__(**kwargs)
            self.beta = K.cast_to_floatx(beta)

        def call(self, inputs):
            return K.sigmoid(self.beta * inputs) * inputs

        def get_config(self):
            config = {'beta': float(self.beta)}
            base_config = super(Swish, self).get_config()
            return dict(list(base_config.items()) + list(config.items()))

        def compute_output_shape(self, input_shape):
            return input_shape
    # swish definiton end
    
    # our hyperarameters
    n_layer1 = {{choice([128, 256, 512])}}
    n_layer2 = {{choice([128, 256, 512])}}
    n_layer3 = {{choice([128, 256, 512])}}
    dropout_1 = {{uniform(0, 0.5)}}
    dropout_2 = {{uniform(0, 0.5)}}
    dropout_3 = {{uniform(0, 0.5)}}
    act = {{choice(['relu', 'leakyrelu', 'swish'])}}
    optim = {{choice(['rmsprop', 'adam', 'sgd'])}}
    n_batch = {{choice([64, 128, 256])}}
    print('a modell hiperparaméterei: ', n_layer1, n_layer2, n_layer3, dropout_1, dropout_2, dropout_3, act, optim, n_batch)
    
    if act == 'relu':
        activation = keras.layers.ReLU()
    elif act == 'leakyrelu':
        activation = keras.layers.LeakyReLU()
    elif act == 'swish':
        activation = Swish(beta=0.3)
    
    model = Sequential()
    model.add(Dense(n_layer1, input_dim=300))
    model.add(activation)
    model.add(Dropout(dropout_1))
    model.add(BatchNormalization())

    model.add(Dense(n_layer2))
    model.add(activation)
    model.add(Dropout(dropout_2))
    model.add(BatchNormalization())

    model.add(Dense(n_layer3))
    model.add(activation)
    model.add(Dropout(dropout_3))
    model.add(BatchNormalization())

    model.add(Dense(3, activation='softmax'))
    
    model.compile(optimizer=optim,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    callbacks = [EarlyStopping(monitor='val_accuracy', patience=3, verbose=0)]
    
    result = model.fit(x_train, y_train,
              batch_size=n_batch,
              epochs=100,
              verbose=2,
              validation_data=(x_test, y_test),
              callbacks=callbacks,
              shuffle=True)

    best_val_acc = np.amax(result.history['val_accuracy']) 
    print('legjobb val_acc:', best_val_acc)
    
    with open('hyperopt-log.csv', 'a') as csv_file:
      csv_file.write(str(n_layer1) + ';')
      csv_file.write(str(n_layer2) + ';')
      csv_file.write(str(n_layer3) + ';')
      csv_file.write(str(dropout_1) + ';')
      csv_file.write(str(dropout_2) + ';')
      csv_file.write(str(dropout_3) + ';')
      csv_file.write(str(act) + ';')
      csv_file.write(str(optim) + ';')
      csv_file.write(str(n_batch) + ';')
      csv_file.write(str(best_val_acc) + '\n')

    return {'loss': -best_val_acc, 'status': STATUS_OK, 'model': model}

# %%
with open('hyperopt-log.csv', 'w') as csv_file:
  csv_file.write('n_layer1' + ';')
  csv_file.write('n_layer2' + ';')
  csv_file.write('n_layer3' + ';')
  csv_file.write('dropout_1' + ';')
  csv_file.write('dropout_2' + ';')
  csv_file.write('dropout_3' + ';')
  csv_file.write('act' + ';')
  csv_file.write('optim' + ';')
  csv_file.write('n_batch' + ';')
  csv_file.write('best_val_acc' + '\n')

# %% [markdown]
# #Notebook download, and upload to colab

# %%
# !pip3 install hyperas
# !pip3 install hyperopt

# %%
import hyperas
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

# %%
best_run, best_model = optim.minimize(model=create_model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=100,
                                          notebook_name='Hyperparameter_optimalization',
                                          trials=Trials())
# Out:
# A streamkimeneten csak az utolsó 5000 sor látható.
# Epoch 9/100
# 108/108 - 1s - loss: 0.5331 - accuracy: 0.7785 - val_loss: 0.6190 - val_accuracy: 0.7497
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.5159 - accuracy: 0.7888 - val_loss: 0.6218 - val_accuracy: 0.7450
#
# Epoch 11/100
# 108/108 - 1s - loss: 0.4983 - accuracy: 0.7912 - val_loss: 0.6230 - val_accuracy: 0.7566
#
# Epoch 12/100
# 108/108 - 1s - loss: 0.4833 - accuracy: 0.8028 - val_loss: 0.6177 - val_accuracy: 0.7530
#
# Epoch 13/100
# 108/108 - 1s - loss: 0.4606 - accuracy: 0.8104 - val_loss: 0.6314 - val_accuracy: 0.7494
#
# Epoch 14/100
# 108/108 - 1s - loss: 0.4492 - accuracy: 0.8176 - val_loss: 0.6199 - val_accuracy: 0.7630
#
# Epoch 15/100
# 108/108 - 1s - loss: 0.4317 - accuracy: 0.8268 - val_loss: 0.6364 - val_accuracy: 0.7567
#
# Epoch 16/100
# 108/108 - 1s - loss: 0.4141 - accuracy: 0.8323 - val_loss: 0.6502 - val_accuracy: 0.7549
#
# Epoch 17/100
# 108/108 - 1s - loss: 0.3950 - accuracy: 0.8385 - val_loss: 0.6642 - val_accuracy: 0.7584
#
# legjobb val_acc:
# 0.7630234956741333
# a modell hiperparaméterei:
# 512
# 128
# 128
# 0.027187411013491536
# 0.1586960643941503
# 0.1452707662970456
# swish
# sgd
# 64
#  29%|██▉       | 29/100 [06:21<16:20, 13.81s/it, best loss: -0.7652366161346436]WARNING:tensorflow:AutoGraph could not transform <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82e97ebe80>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82e97ebe80>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82e97ebe80>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82e97ebe80>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/100
# 215/215 - 1s - loss: 0.9601 - accuracy: 0.5872 - val_loss: 0.7787 - val_accuracy: 0.6956
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7928 - accuracy: 0.6629 - val_loss: 0.7173 - val_accuracy: 0.7123
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.7575 - accuracy: 0.6806 - val_loss: 0.6932 - val_accuracy: 0.7171
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.7193 - accuracy: 0.6973 - val_loss: 0.6724 - val_accuracy: 0.7257
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6963 - accuracy: 0.7113 - val_loss: 0.6679 - val_accuracy: 0.7273
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.6853 - accuracy: 0.7127 - val_loss: 0.6591 - val_accuracy: 0.7314
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.6705 - accuracy: 0.7195 - val_loss: 0.6534 - val_accuracy: 0.7353
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.6629 - accuracy: 0.7235 - val_loss: 0.6456 - val_accuracy: 0.7438
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.6502 - accuracy: 0.7291 - val_loss: 0.6465 - val_accuracy: 0.7377
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.6399 - accuracy: 0.7329 - val_loss: 0.6440 - val_accuracy: 0.7407
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.6358 - accuracy: 0.7355 - val_loss: 0.6391 - val_accuracy: 0.7424
#
# legjobb val_acc:
# 0.7437861561775208
# a modell hiperparaméterei:
# 512
# 128
# 128
# 0.1804757691108304
# 0.33210730506671915
# 0.257704976822918
# relu
# adam
# 128
# Epoch 1/100
# 108/108 - 1s - loss: 0.9993 - accuracy: 0.5695 - val_loss: 0.7388 - val_accuracy: 0.6835
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.7689 - accuracy: 0.6703 - val_loss: 0.6495 - val_accuracy: 0.7252
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.6817 - accuracy: 0.7161 - val_loss: 0.6285 - val_accuracy: 0.7349
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.6246 - accuracy: 0.7406 - val_loss: 0.6081 - val_accuracy: 0.7400
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.5898 - accuracy: 0.7546 - val_loss: 0.6047 - val_accuracy: 0.7460
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.5504 - accuracy: 0.7714 - val_loss: 0.5908 - val_accuracy: 0.7530
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.5217 - accuracy: 0.7874 - val_loss: 0.5971 - val_accuracy: 0.7543
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.5103 - accuracy: 0.7918 - val_loss: 0.5994 - val_accuracy: 0.7549
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.4802 - accuracy: 0.8055 - val_loss: 0.5913 - val_accuracy: 0.7572
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.4564 - accuracy: 0.8143 - val_loss: 0.5951 - val_accuracy: 0.7606
#
# Epoch 11/100
# 108/108 - 1s - loss: 0.4317 - accuracy: 0.8263 - val_loss: 0.5944 - val_accuracy: 0.7591
#
# Epoch 12/100
# 108/108 - 1s - loss: 0.4245 - accuracy: 0.8290 - val_loss: 0.5905 - val_accuracy: 0.7646
#
# Epoch 13/100
# 108/108 - 1s - loss: 0.4050 - accuracy: 0.8363 - val_loss: 0.6035 - val_accuracy: 0.7639
#
# Epoch 14/100
# 108/108 - 1s - loss: 0.3849 - accuracy: 0.8461 - val_loss: 0.6328 - val_accuracy: 0.7572
#
# Epoch 15/100
# 108/108 - 1s - loss: 0.3600 - accuracy: 0.8547 - val_loss: 0.6165 - val_accuracy: 0.7632
#
# legjobb val_acc:
# 0.7645556926727295
# a modell hiperparaméterei:
# 512
# 128
# 128
# 0.0035437029810986287
# 0.30472092824677627
# 0.24550875004962308
# relu
# adam
# 128
# Epoch 1/100
# 108/108 - 1s - loss: 0.9539 - accuracy: 0.6006 - val_loss: 0.7266 - val_accuracy: 0.6903
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.7117 - accuracy: 0.7066 - val_loss: 0.6487 - val_accuracy: 0.7257
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.6323 - accuracy: 0.7375 - val_loss: 0.6270 - val_accuracy: 0.7441
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.5666 - accuracy: 0.7665 - val_loss: 0.6159 - val_accuracy: 0.7482
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.5247 - accuracy: 0.7827 - val_loss: 0.5984 - val_accuracy: 0.7538
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.4734 - accuracy: 0.8080 - val_loss: 0.6362 - val_accuracy: 0.7458
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.4275 - accuracy: 0.8304 - val_loss: 0.6337 - val_accuracy: 0.7501
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.3857 - accuracy: 0.8456 - val_loss: 0.6556 - val_accuracy: 0.7486
#
# legjobb val_acc:
# 0.7538304328918457
# a modell hiperparaméterei:
# 512
# 128
# 128
# 0.1539335928675344
# 0.3426713369259134
# 0.4263664014096994
# relu
# adam
# 128
# Epoch 1/100
# 108/108 - 1s - loss: 1.0167 - accuracy: 0.5701 - val_loss: 0.7407 - val_accuracy: 0.6842
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.7762 - accuracy: 0.6793 - val_loss: 0.6522 - val_accuracy: 0.7268
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.6915 - accuracy: 0.7145 - val_loss: 0.6346 - val_accuracy: 0.7332
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.6398 - accuracy: 0.7339 - val_loss: 0.6141 - val_accuracy: 0.7406
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.5962 - accuracy: 0.7536 - val_loss: 0.6048 - val_accuracy: 0.7470
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.5733 - accuracy: 0.7655 - val_loss: 0.6029 - val_accuracy: 0.7443
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.5388 - accuracy: 0.7815 - val_loss: 0.6031 - val_accuracy: 0.7554
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.5125 - accuracy: 0.7896 - val_loss: 0.5982 - val_accuracy: 0.7576
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.4878 - accuracy: 0.7996 - val_loss: 0.5969 - val_accuracy: 0.7555
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.4502 - accuracy: 0.8207 - val_loss: 0.5989 - val_accuracy: 0.7577
#
# Epoch 11/100
# 108/108 - 1s - loss: 0.4460 - accuracy: 0.8247 - val_loss: 0.6263 - val_accuracy: 0.7506
#
# Epoch 12/100
# 108/108 - 1s - loss: 0.4146 - accuracy: 0.8363 - val_loss: 0.6205 - val_accuracy: 0.7564
#
# Epoch 13/100
# 108/108 - 1s - loss: 0.4043 - accuracy: 0.8408 - val_loss: 0.6231 - val_accuracy: 0.7600
#
# Epoch 14/100
# 108/108 - 1s - loss: 0.3797 - accuracy: 0.8528 - val_loss: 0.6342 - val_accuracy: 0.7612
#
# Epoch 15/100
# 108/108 - 1s - loss: 0.3735 - accuracy: 0.8519 - val_loss: 0.6528 - val_accuracy: 0.7588
#
# Epoch 16/100
# 108/108 - 1s - loss: 0.3539 - accuracy: 0.8595 - val_loss: 0.6604 - val_accuracy: 0.7574
#
# Epoch 17/100
# 108/108 - 1s - loss: 0.3308 - accuracy: 0.8717 - val_loss: 0.6614 - val_accuracy: 0.7603
#
# legjobb val_acc:
# 0.7611508369445801
# a modell hiperparaméterei:
# 128
# 128
# 256
# 0.20716324230032684
# 0.458030110833484
# 0.29352987674893183
# relu
# adam
# 128
# Epoch 1/100
# 108/108 - 1s - loss: 1.1409 - accuracy: 0.5006 - val_loss: 0.7976 - val_accuracy: 0.6547
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.8866 - accuracy: 0.6182 - val_loss: 0.7148 - val_accuracy: 0.7000
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.7847 - accuracy: 0.6652 - val_loss: 0.6860 - val_accuracy: 0.7082
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.7379 - accuracy: 0.6914 - val_loss: 0.6724 - val_accuracy: 0.7109
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.6954 - accuracy: 0.7062 - val_loss: 0.6509 - val_accuracy: 0.7230
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.6622 - accuracy: 0.7225 - val_loss: 0.6360 - val_accuracy: 0.7354
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.6440 - accuracy: 0.7345 - val_loss: 0.6284 - val_accuracy: 0.7383
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.6249 - accuracy: 0.7431 - val_loss: 0.6248 - val_accuracy: 0.7394
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.6071 - accuracy: 0.7489 - val_loss: 0.6223 - val_accuracy: 0.7399
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.5934 - accuracy: 0.7529 - val_loss: 0.6141 - val_accuracy: 0.7412
#
# Epoch 11/100
# 108/108 - 1s - loss: 0.5807 - accuracy: 0.7602 - val_loss: 0.6096 - val_accuracy: 0.7416
#
# Epoch 12/100
# 108/108 - 1s - loss: 0.5699 - accuracy: 0.7672 - val_loss: 0.6048 - val_accuracy: 0.7475
#
# Epoch 13/100
# 108/108 - 1s - loss: 0.5527 - accuracy: 0.7742 - val_loss: 0.6068 - val_accuracy: 0.7521
#
# Epoch 14/100
# 108/108 - 1s - loss: 0.5460 - accuracy: 0.7762 - val_loss: 0.6039 - val_accuracy: 0.7494
#
# Epoch 15/100
# 108/108 - 1s - loss: 0.5260 - accuracy: 0.7839 - val_loss: 0.6053 - val_accuracy: 0.7533
#
# Epoch 16/100
# 108/108 - 1s - loss: 0.5272 - accuracy: 0.7836 - val_loss: 0.6085 - val_accuracy: 0.7465
#
# Epoch 17/100
# 108/108 - 1s - loss: 0.5210 - accuracy: 0.7848 - val_loss: 0.6009 - val_accuracy: 0.7572
#
# Epoch 18/100
# 108/108 - 1s - loss: 0.5164 - accuracy: 0.7859 - val_loss: 0.5940 - val_accuracy: 0.7574
#
# Epoch 19/100
# 108/108 - 1s - loss: 0.4929 - accuracy: 0.7993 - val_loss: 0.6018 - val_accuracy: 0.7598
#
# Epoch 20/100
# 108/108 - 1s - loss: 0.4902 - accuracy: 0.7981 - val_loss: 0.6098 - val_accuracy: 0.7535
#
# Epoch 21/100
# 108/108 - 1s - loss: 0.4865 - accuracy: 0.8042 - val_loss: 0.6083 - val_accuracy: 0.7549
#
# Epoch 22/100
# 108/108 - 1s - loss: 0.4661 - accuracy: 0.8145 - val_loss: 0.6073 - val_accuracy: 0.7538
#
# legjobb val_acc:
# 0.7597888708114624
# a modell hiperparaméterei:
# 512
# 128
# 128
# 0.2488774267966467
# 0.3146661808396619
# 0.2754882207076294
# relu
# sgd
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.1807 - accuracy: 0.4648 - val_loss: 0.8683 - val_accuracy: 0.6216
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.9629 - accuracy: 0.5565 - val_loss: 0.8084 - val_accuracy: 0.6568
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.8867 - accuracy: 0.5982 - val_loss: 0.7724 - val_accuracy: 0.6699
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.8385 - accuracy: 0.6291 - val_loss: 0.7479 - val_accuracy: 0.6786
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.8074 - accuracy: 0.6420 - val_loss: 0.7250 - val_accuracy: 0.6937
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.7818 - accuracy: 0.6568 - val_loss: 0.7074 - val_accuracy: 0.6990
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.7594 - accuracy: 0.6659 - val_loss: 0.6953 - val_accuracy: 0.7074
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.7423 - accuracy: 0.6826 - val_loss: 0.6860 - val_accuracy: 0.7108
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.7299 - accuracy: 0.6911 - val_loss: 0.6771 - val_accuracy: 0.7138
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.7137 - accuracy: 0.6906 - val_loss: 0.6680 - val_accuracy: 0.7165
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.7021 - accuracy: 0.7039 - val_loss: 0.6612 - val_accuracy: 0.7223
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.6876 - accuracy: 0.7080 - val_loss: 0.6555 - val_accuracy: 0.7249
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.6789 - accuracy: 0.7144 - val_loss: 0.6500 - val_accuracy: 0.7285
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.6735 - accuracy: 0.7149 - val_loss: 0.6444 - val_accuracy: 0.7307
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.6664 - accuracy: 0.7200 - val_loss: 0.6409 - val_accuracy: 0.7295
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.6520 - accuracy: 0.7291 - val_loss: 0.6365 - val_accuracy: 0.7322
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.6452 - accuracy: 0.7307 - val_loss: 0.6328 - val_accuracy: 0.7346
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.6391 - accuracy: 0.7314 - val_loss: 0.6294 - val_accuracy: 0.7365
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.6307 - accuracy: 0.7386 - val_loss: 0.6263 - val_accuracy: 0.7356
#
# Epoch 20/100
# 215/215 - 1s - loss: 0.6205 - accuracy: 0.7472 - val_loss: 0.6229 - val_accuracy: 0.7383
#
# Epoch 21/100
# 215/215 - 1s - loss: 0.6152 - accuracy: 0.7462 - val_loss: 0.6187 - val_accuracy: 0.7407
#
# Epoch 22/100
# 215/215 - 1s - loss: 0.6114 - accuracy: 0.7470 - val_loss: 0.6181 - val_accuracy: 0.7397
#
# Epoch 23/100
# 215/215 - 1s - loss: 0.6001 - accuracy: 0.7531 - val_loss: 0.6148 - val_accuracy: 0.7395
#
# Epoch 24/100
# 215/215 - 1s - loss: 0.6003 - accuracy: 0.7511 - val_loss: 0.6137 - val_accuracy: 0.7445
#
# Epoch 25/100
# 215/215 - 1s - loss: 0.5922 - accuracy: 0.7539 - val_loss: 0.6101 - val_accuracy: 0.7445
#
# Epoch 26/100
# 215/215 - 1s - loss: 0.5905 - accuracy: 0.7541 - val_loss: 0.6089 - val_accuracy: 0.7434
#
# Epoch 27/100
# 215/215 - 1s - loss: 0.5800 - accuracy: 0.7622 - val_loss: 0.6060 - val_accuracy: 0.7477
#
# Epoch 28/100
# 215/215 - 1s - loss: 0.5746 - accuracy: 0.7618 - val_loss: 0.6040 - val_accuracy: 0.7492
#
# Epoch 29/100
# 215/215 - 1s - loss: 0.5659 - accuracy: 0.7670 - val_loss: 0.6044 - val_accuracy: 0.7497
#
# Epoch 30/100
# 215/215 - 1s - loss: 0.5745 - accuracy: 0.7618 - val_loss: 0.6014 - val_accuracy: 0.7533
#
# Epoch 31/100
# 215/215 - 1s - loss: 0.5651 - accuracy: 0.7667 - val_loss: 0.6017 - val_accuracy: 0.7458
#
# Epoch 32/100
# 215/215 - 1s - loss: 0.5530 - accuracy: 0.7744 - val_loss: 0.5992 - val_accuracy: 0.7496
#
# Epoch 33/100
# 215/215 - 1s - loss: 0.5524 - accuracy: 0.7726 - val_loss: 0.5980 - val_accuracy: 0.7509
#
# legjobb val_acc:
# 0.7533197402954102
# a modell hiperparaméterei:
# 512
# 128
# 128
# 0.32292898012348
# 0.22213167902522019
# 0.32608469803463924
# relu
# adam
# 128
# Epoch 1/100
# 108/108 - 1s - loss: 1.0412 - accuracy: 0.5616 - val_loss: 0.7343 - val_accuracy: 0.6919
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.7862 - accuracy: 0.6673 - val_loss: 0.6664 - val_accuracy: 0.7181
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.7093 - accuracy: 0.7049 - val_loss: 0.6352 - val_accuracy: 0.7337
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.6523 - accuracy: 0.7335 - val_loss: 0.6230 - val_accuracy: 0.7387
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.6153 - accuracy: 0.7407 - val_loss: 0.6013 - val_accuracy: 0.7496
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.5853 - accuracy: 0.7548 - val_loss: 0.5984 - val_accuracy: 0.7492
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.5594 - accuracy: 0.7699 - val_loss: 0.5950 - val_accuracy: 0.7506
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.5339 - accuracy: 0.7799 - val_loss: 0.5907 - val_accuracy: 0.7518
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.5164 - accuracy: 0.7920 - val_loss: 0.5921 - val_accuracy: 0.7557
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.4968 - accuracy: 0.7973 - val_loss: 0.5879 - val_accuracy: 0.7584
#
# Epoch 11/100
# 108/108 - 1s - loss: 0.4844 - accuracy: 0.7991 - val_loss: 0.5915 - val_accuracy: 0.7629
#
# Epoch 12/100
# 108/108 - 1s - loss: 0.4652 - accuracy: 0.8102 - val_loss: 0.5897 - val_accuracy: 0.7649
#
# Epoch 13/100
# 108/108 - 1s - loss: 0.4506 - accuracy: 0.8172 - val_loss: 0.5858 - val_accuracy: 0.7617
#
# Epoch 14/100
# 108/108 - 1s - loss: 0.4316 - accuracy: 0.8269 - val_loss: 0.5987 - val_accuracy: 0.7634
#
# Epoch 15/100
# 108/108 - 1s - loss: 0.4228 - accuracy: 0.8304 - val_loss: 0.5992 - val_accuracy: 0.7630
#
# legjobb val_acc:
# 0.7648961544036865
# a modell hiperparaméterei:
# 512
# 128
# 256
# 0.32694532753376737
# 0.2161864252452701
# 0.33046607861322597
# relu
# rmsprop
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9859 - accuracy: 0.5842 - val_loss: 0.6960 - val_accuracy: 0.7068
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7531 - accuracy: 0.6833 - val_loss: 0.6445 - val_accuracy: 0.7346
#
# Epoch 3/100
# 215/215 - 2s - loss: 0.6702 - accuracy: 0.7219 - val_loss: 0.6343 - val_accuracy: 0.7383
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6162 - accuracy: 0.7436 - val_loss: 0.6278 - val_accuracy: 0.7371
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.5796 - accuracy: 0.7580 - val_loss: 0.6130 - val_accuracy: 0.7463
#
# Epoch 6/100
# 215/215 - 2s - loss: 0.5535 - accuracy: 0.7712 - val_loss: 0.6000 - val_accuracy: 0.7506
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5195 - accuracy: 0.7858 - val_loss: 0.5929 - val_accuracy: 0.7603
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.4984 - accuracy: 0.7960 - val_loss: 0.5952 - val_accuracy: 0.7514
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.4714 - accuracy: 0.8077 - val_loss: 0.6047 - val_accuracy: 0.7572
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.4458 - accuracy: 0.8214 - val_loss: 0.6020 - val_accuracy: 0.7601
#
# legjobb val_acc:
# 0.7602996230125427
# a modell hiperparaméterei:
# 512
# 256
# 512
# 0.4269112358670871
# 0.09152057278163307
# 0.4296624885574465
# relu
# sgd
# 128
# Epoch 1/100
# 108/108 - 1s - loss: 1.3133 - accuracy: 0.4254 - val_loss: 0.9267 - val_accuracy: 0.5832
#
# Epoch 2/100
# 108/108 - 1s - loss: 1.0772 - accuracy: 0.5175 - val_loss: 0.8667 - val_accuracy: 0.6064
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.9841 - accuracy: 0.5605 - val_loss: 0.8297 - val_accuracy: 0.6297
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.9304 - accuracy: 0.5858 - val_loss: 0.8101 - val_accuracy: 0.6381
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.8888 - accuracy: 0.6055 - val_loss: 0.7896 - val_accuracy: 0.6513
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.8596 - accuracy: 0.6184 - val_loss: 0.7731 - val_accuracy: 0.6583
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.8348 - accuracy: 0.6317 - val_loss: 0.7558 - val_accuracy: 0.6670
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.8191 - accuracy: 0.6476 - val_loss: 0.7457 - val_accuracy: 0.6772
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.7972 - accuracy: 0.6495 - val_loss: 0.7350 - val_accuracy: 0.6816
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.7840 - accuracy: 0.6565 - val_loss: 0.7244 - val_accuracy: 0.6878
#
# Epoch 11/100
# 108/108 - 1s - loss: 0.7720 - accuracy: 0.6672 - val_loss: 0.7175 - val_accuracy: 0.6919
#
# Epoch 12/100
# 108/108 - 1s - loss: 0.7609 - accuracy: 0.6675 - val_loss: 0.7092 - val_accuracy: 0.6925
#
# Epoch 13/100
# 108/108 - 1s - loss: 0.7458 - accuracy: 0.6796 - val_loss: 0.7048 - val_accuracy: 0.6988
#
# Epoch 14/100
# 108/108 - 1s - loss: 0.7361 - accuracy: 0.6815 - val_loss: 0.6982 - val_accuracy: 0.7002
#
# Epoch 15/100
# 108/108 - 1s - loss: 0.7243 - accuracy: 0.6874 - val_loss: 0.6942 - val_accuracy: 0.7029
#
# Epoch 16/100
# 108/108 - 1s - loss: 0.7273 - accuracy: 0.6907 - val_loss: 0.6857 - val_accuracy: 0.7085
#
# Epoch 17/100
# 108/108 - 1s - loss: 0.7178 - accuracy: 0.6901 - val_loss: 0.6833 - val_accuracy: 0.7082
#
# Epoch 18/100
# 108/108 - 1s - loss: 0.7096 - accuracy: 0.6976 - val_loss: 0.6772 - val_accuracy: 0.7133
#
# Epoch 19/100
# 108/108 - 1s - loss: 0.7068 - accuracy: 0.6970 - val_loss: 0.6727 - val_accuracy: 0.7118
#
# Epoch 20/100
# 108/108 - 1s - loss: 0.6998 - accuracy: 0.7035 - val_loss: 0.6678 - val_accuracy: 0.7155
#
# Epoch 21/100
# 108/108 - 1s - loss: 0.6911 - accuracy: 0.7070 - val_loss: 0.6651 - val_accuracy: 0.7171
#
# Epoch 22/100
# 108/108 - 1s - loss: 0.6819 - accuracy: 0.7113 - val_loss: 0.6620 - val_accuracy: 0.7182
#
# Epoch 23/100
# 108/108 - 1s - loss: 0.6746 - accuracy: 0.7170 - val_loss: 0.6594 - val_accuracy: 0.7184
#
# Epoch 24/100
# 108/108 - 1s - loss: 0.6751 - accuracy: 0.7149 - val_loss: 0.6571 - val_accuracy: 0.7211
#
# Epoch 25/100
# 108/108 - 1s - loss: 0.6675 - accuracy: 0.7196 - val_loss: 0.6541 - val_accuracy: 0.7217
#
# Epoch 26/100
# 108/108 - 1s - loss: 0.6758 - accuracy: 0.7183 - val_loss: 0.6497 - val_accuracy: 0.7227
#
# Epoch 27/100
# 108/108 - 1s - loss: 0.6650 - accuracy: 0.7213 - val_loss: 0.6504 - val_accuracy: 0.7227
#
# Epoch 28/100
# 108/108 - 1s - loss: 0.6579 - accuracy: 0.7195 - val_loss: 0.6457 - val_accuracy: 0.7261
#
# Epoch 29/100
# 108/108 - 1s - loss: 0.6539 - accuracy: 0.7217 - val_loss: 0.6441 - val_accuracy: 0.7266
#
# Epoch 30/100
# 108/108 - 1s - loss: 0.6510 - accuracy: 0.7221 - val_loss: 0.6441 - val_accuracy: 0.7254
#
# Epoch 31/100
# 108/108 - 1s - loss: 0.6500 - accuracy: 0.7282 - val_loss: 0.6401 - val_accuracy: 0.7283
#
# Epoch 32/100
# 108/108 - 1s - loss: 0.6437 - accuracy: 0.7286 - val_loss: 0.6386 - val_accuracy: 0.7286
#
# Epoch 33/100
# 108/108 - 1s - loss: 0.6454 - accuracy: 0.7265 - val_loss: 0.6357 - val_accuracy: 0.7288
#
# Epoch 34/100
# 108/108 - 1s - loss: 0.6363 - accuracy: 0.7340 - val_loss: 0.6356 - val_accuracy: 0.7302
#
# Epoch 35/100
# 108/108 - 1s - loss: 0.6368 - accuracy: 0.7369 - val_loss: 0.6329 - val_accuracy: 0.7315
#
# Epoch 36/100
# 108/108 - 1s - loss: 0.6321 - accuracy: 0.7351 - val_loss: 0.6319 - val_accuracy: 0.7336
#
# Epoch 37/100
# 108/108 - 1s - loss: 0.6237 - accuracy: 0.7387 - val_loss: 0.6313 - val_accuracy: 0.7322
#
# Epoch 38/100
# 108/108 - 1s - loss: 0.6158 - accuracy: 0.7402 - val_loss: 0.6283 - val_accuracy: 0.7354
#
# Epoch 39/100
# 108/108 - 1s - loss: 0.6195 - accuracy: 0.7429 - val_loss: 0.6262 - val_accuracy: 0.7368
#
# Epoch 40/100
# 108/108 - 1s - loss: 0.6130 - accuracy: 0.7443 - val_loss: 0.6259 - val_accuracy: 0.7354
#
# Epoch 41/100
# 108/108 - 1s - loss: 0.6141 - accuracy: 0.7395 - val_loss: 0.6220 - val_accuracy: 0.7380
#
# Epoch 42/100
# 108/108 - 1s - loss: 0.6170 - accuracy: 0.7415 - val_loss: 0.6237 - val_accuracy: 0.7358
#
# Epoch 43/100
# 108/108 - 1s - loss: 0.6129 - accuracy: 0.7426 - val_loss: 0.6218 - val_accuracy: 0.7385
#
# Epoch 44/100
# 108/108 - 1s - loss: 0.6035 - accuracy: 0.7504 - val_loss: 0.6226 - val_accuracy: 0.7360
#
# Epoch 45/100
# 108/108 - 1s - loss: 0.6084 - accuracy: 0.7481 - val_loss: 0.6224 - val_accuracy: 0.7353
#
# Epoch 46/100
# 108/108 - 1s - loss: 0.6041 - accuracy: 0.7481 - val_loss: 0.6212 - val_accuracy: 0.7361
#
# legjobb val_acc:
# 0.7385087013244629
# a modell hiperparaméterei:
# 128
# 512
# 128
# 0.3195271159574968
# 0.2809919628304628
# 0.4338141974748251
# relu
# adam
# 256
# Epoch 1/100
# 54/54 - 0s - loss: 1.1664 - accuracy: 0.5169 - val_loss: 0.8739 - val_accuracy: 0.5764
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.9176 - accuracy: 0.6150 - val_loss: 0.7382 - val_accuracy: 0.6956
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.8055 - accuracy: 0.6618 - val_loss: 0.6781 - val_accuracy: 0.7177
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.7377 - accuracy: 0.6894 - val_loss: 0.6533 - val_accuracy: 0.7249
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6953 - accuracy: 0.7100 - val_loss: 0.6394 - val_accuracy: 0.7307
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6602 - accuracy: 0.7239 - val_loss: 0.6281 - val_accuracy: 0.7343
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.6438 - accuracy: 0.7289 - val_loss: 0.6225 - val_accuracy: 0.7377
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.6259 - accuracy: 0.7397 - val_loss: 0.6248 - val_accuracy: 0.7406
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.6068 - accuracy: 0.7459 - val_loss: 0.6170 - val_accuracy: 0.7426
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.5921 - accuracy: 0.7544 - val_loss: 0.6195 - val_accuracy: 0.7370
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.5778 - accuracy: 0.7622 - val_loss: 0.6056 - val_accuracy: 0.7475
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.5579 - accuracy: 0.7688 - val_loss: 0.6152 - val_accuracy: 0.7448
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.5486 - accuracy: 0.7726 - val_loss: 0.6056 - val_accuracy: 0.7506
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.5349 - accuracy: 0.7790 - val_loss: 0.6097 - val_accuracy: 0.7489
#
# Epoch 15/100
# 54/54 - 0s - loss: 0.5239 - accuracy: 0.7843 - val_loss: 0.6051 - val_accuracy: 0.7528
#
# Epoch 16/100
# 54/54 - 0s - loss: 0.5181 - accuracy: 0.7928 - val_loss: 0.6115 - val_accuracy: 0.7540
#
# Epoch 17/100
# 54/54 - 0s - loss: 0.4998 - accuracy: 0.7943 - val_loss: 0.6134 - val_accuracy: 0.7518
#
# Epoch 18/100
# 54/54 - 0s - loss: 0.4905 - accuracy: 0.8031 - val_loss: 0.6100 - val_accuracy: 0.7562
#
# Epoch 19/100
# 54/54 - 0s - loss: 0.4859 - accuracy: 0.8013 - val_loss: 0.6174 - val_accuracy: 0.7540
#
# Epoch 20/100
# 54/54 - 0s - loss: 0.4748 - accuracy: 0.8104 - val_loss: 0.6136 - val_accuracy: 0.7520
#
# Epoch 21/100
# 54/54 - 0s - loss: 0.4588 - accuracy: 0.8153 - val_loss: 0.6180 - val_accuracy: 0.7530
#
# legjobb val_acc:
# 0.7562138438224792
# a modell hiperparaméterei:
# 512
# 128
# 128
# 0.3593433530010136
# 0.21880463535340797
# 0.4911238980854753
# relu
# adam
# 128
# Epoch 1/100
# 108/108 - 1s - loss: 1.0517 - accuracy: 0.5462 - val_loss: 0.7301 - val_accuracy: 0.6912
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.8018 - accuracy: 0.6587 - val_loss: 0.6680 - val_accuracy: 0.7143
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.7150 - accuracy: 0.7003 - val_loss: 0.6454 - val_accuracy: 0.7254
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.6609 - accuracy: 0.7209 - val_loss: 0.6211 - val_accuracy: 0.7394
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.6265 - accuracy: 0.7395 - val_loss: 0.6073 - val_accuracy: 0.7419
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.6001 - accuracy: 0.7484 - val_loss: 0.6020 - val_accuracy: 0.7458
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.5841 - accuracy: 0.7588 - val_loss: 0.5957 - val_accuracy: 0.7497
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.5575 - accuracy: 0.7683 - val_loss: 0.5809 - val_accuracy: 0.7623
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.5364 - accuracy: 0.7769 - val_loss: 0.5878 - val_accuracy: 0.7564
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.5184 - accuracy: 0.7890 - val_loss: 0.5853 - val_accuracy: 0.7591
#
# Epoch 11/100
# 108/108 - 1s - loss: 0.5053 - accuracy: 0.7929 - val_loss: 0.5793 - val_accuracy: 0.7629
#
# Epoch 12/100
# 108/108 - 1s - loss: 0.4860 - accuracy: 0.8033 - val_loss: 0.5897 - val_accuracy: 0.7656
#
# Epoch 13/100
# 108/108 - 1s - loss: 0.4783 - accuracy: 0.8066 - val_loss: 0.5923 - val_accuracy: 0.7618
#
# Epoch 14/100
# 108/108 - 1s - loss: 0.4606 - accuracy: 0.8166 - val_loss: 0.6011 - val_accuracy: 0.7608
#
# Epoch 15/100
# 108/108 - 1s - loss: 0.4513 - accuracy: 0.8178 - val_loss: 0.5805 - val_accuracy: 0.7726
#
# Epoch 16/100
# 108/108 - 1s - loss: 0.4423 - accuracy: 0.8202 - val_loss: 0.6034 - val_accuracy: 0.7625
#
# Epoch 17/100
# 108/108 - 1s - loss: 0.4217 - accuracy: 0.8331 - val_loss: 0.5975 - val_accuracy: 0.7666
#
# Epoch 18/100
# 108/108 - 1s - loss: 0.4201 - accuracy: 0.8285 - val_loss: 0.6009 - val_accuracy: 0.7640
#
# legjobb val_acc:
# 0.7725570201873779
# a modell hiperparaméterei:
# 512
# 256
# 512
# 0.49121135629209756
# 0.17982403327177215
# 0.48861636675884024
# relu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 0s - loss: 1.0750 - accuracy: 0.5563 - val_loss: 0.7985 - val_accuracy: 0.6338
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.8444 - accuracy: 0.6506 - val_loss: 0.6910 - val_accuracy: 0.7045
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7513 - accuracy: 0.6870 - val_loss: 0.6622 - val_accuracy: 0.7217
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.6860 - accuracy: 0.7134 - val_loss: 0.6296 - val_accuracy: 0.7358
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6407 - accuracy: 0.7351 - val_loss: 0.6204 - val_accuracy: 0.7457
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6190 - accuracy: 0.7441 - val_loss: 0.6094 - val_accuracy: 0.7446
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.5882 - accuracy: 0.7578 - val_loss: 0.6105 - val_accuracy: 0.7467
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.5632 - accuracy: 0.7686 - val_loss: 0.6037 - val_accuracy: 0.7577
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.5396 - accuracy: 0.7813 - val_loss: 0.5990 - val_accuracy: 0.7572
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.5213 - accuracy: 0.7866 - val_loss: 0.5979 - val_accuracy: 0.7596
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.5030 - accuracy: 0.7937 - val_loss: 0.6177 - val_accuracy: 0.7492
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.4924 - accuracy: 0.7962 - val_loss: 0.5943 - val_accuracy: 0.7603
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.4725 - accuracy: 0.8077 - val_loss: 0.6047 - val_accuracy: 0.7615
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.4560 - accuracy: 0.8115 - val_loss: 0.5842 - val_accuracy: 0.7617
#
# Epoch 15/100
# 54/54 - 0s - loss: 0.4477 - accuracy: 0.8174 - val_loss: 0.5913 - val_accuracy: 0.7629
#
# Epoch 16/100
# 54/54 - 0s - loss: 0.4217 - accuracy: 0.8279 - val_loss: 0.6018 - val_accuracy: 0.7649
#
# Epoch 17/100
# 54/54 - 0s - loss: 0.4142 - accuracy: 0.8344 - val_loss: 0.6028 - val_accuracy: 0.7668
#
# Epoch 18/100
# 54/54 - 0s - loss: 0.3998 - accuracy: 0.8413 - val_loss: 0.6000 - val_accuracy: 0.7703
#
# Epoch 19/100
# 54/54 - 0s - loss: 0.3890 - accuracy: 0.8436 - val_loss: 0.6059 - val_accuracy: 0.7639
#
# Epoch 20/100
# 54/54 - 0s - loss: 0.3746 - accuracy: 0.8505 - val_loss: 0.5997 - val_accuracy: 0.7715
#
# Epoch 21/100
# 54/54 - 0s - loss: 0.3656 - accuracy: 0.8520 - val_loss: 0.6366 - val_accuracy: 0.7703
#
# Epoch 22/100
# 54/54 - 0s - loss: 0.3522 - accuracy: 0.8614 - val_loss: 0.6294 - val_accuracy: 0.7688
#
# Epoch 23/100
# 54/54 - 0s - loss: 0.3378 - accuracy: 0.8655 - val_loss: 0.6465 - val_accuracy: 0.7714
#
# legjobb val_acc:
# 0.7715355753898621
# a modell hiperparaméterei:
# 128
# 256
# 512
# 0.4904218358161693
# 0.18104971348687465
# 0.4809466552454726
# relu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 1s - loss: 1.1834 - accuracy: 0.5046 - val_loss: 0.9191 - val_accuracy: 0.5393
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.9509 - accuracy: 0.5940 - val_loss: 0.7722 - val_accuracy: 0.6692
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.8419 - accuracy: 0.6444 - val_loss: 0.7141 - val_accuracy: 0.6971
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.7792 - accuracy: 0.6682 - val_loss: 0.6769 - val_accuracy: 0.7087
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.7327 - accuracy: 0.6936 - val_loss: 0.6678 - val_accuracy: 0.7152
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.7042 - accuracy: 0.7079 - val_loss: 0.6587 - val_accuracy: 0.7234
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.6723 - accuracy: 0.7173 - val_loss: 0.6564 - val_accuracy: 0.7259
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.6605 - accuracy: 0.7262 - val_loss: 0.6492 - val_accuracy: 0.7283
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.6408 - accuracy: 0.7331 - val_loss: 0.6407 - val_accuracy: 0.7326
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.6300 - accuracy: 0.7389 - val_loss: 0.6354 - val_accuracy: 0.7409
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.6143 - accuracy: 0.7452 - val_loss: 0.6421 - val_accuracy: 0.7411
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.6047 - accuracy: 0.7533 - val_loss: 0.6289 - val_accuracy: 0.7402
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.5896 - accuracy: 0.7610 - val_loss: 0.6268 - val_accuracy: 0.7445
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.5795 - accuracy: 0.7653 - val_loss: 0.6223 - val_accuracy: 0.7453
#
# Epoch 15/100
# 54/54 - 0s - loss: 0.5842 - accuracy: 0.7607 - val_loss: 0.6259 - val_accuracy: 0.7458
#
# Epoch 16/100
# 54/54 - 0s - loss: 0.5616 - accuracy: 0.7678 - val_loss: 0.6294 - val_accuracy: 0.7451
#
# Epoch 17/100
# 54/54 - 0s - loss: 0.5515 - accuracy: 0.7764 - val_loss: 0.6123 - val_accuracy: 0.7589
#
# Epoch 18/100
# 54/54 - 0s - loss: 0.5503 - accuracy: 0.7751 - val_loss: 0.6146 - val_accuracy: 0.7516
#
# Epoch 19/100
# 54/54 - 0s - loss: 0.5318 - accuracy: 0.7824 - val_loss: 0.6052 - val_accuracy: 0.7543
#
# Epoch 20/100
# 54/54 - 0s - loss: 0.5372 - accuracy: 0.7814 - val_loss: 0.6225 - val_accuracy: 0.7537
#
# legjobb val_acc:
# 0.7589377164840698
# a modell hiperparaméterei:
# 512
# 256
# 512
# 0.47159917782249167
# 0.26071651430215376
# 0.49971551242455414
# relu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 1s - loss: 1.0799 - accuracy: 0.5555 - val_loss: 0.7874 - val_accuracy: 0.6539
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.8557 - accuracy: 0.6479 - val_loss: 0.6885 - val_accuracy: 0.7104
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7405 - accuracy: 0.6914 - val_loss: 0.6462 - val_accuracy: 0.7285
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.6911 - accuracy: 0.7104 - val_loss: 0.6363 - val_accuracy: 0.7339
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6478 - accuracy: 0.7325 - val_loss: 0.6211 - val_accuracy: 0.7409
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6149 - accuracy: 0.7446 - val_loss: 0.6194 - val_accuracy: 0.7470
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.5917 - accuracy: 0.7620 - val_loss: 0.6106 - val_accuracy: 0.7543
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.5673 - accuracy: 0.7665 - val_loss: 0.6086 - val_accuracy: 0.7528
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.5481 - accuracy: 0.7772 - val_loss: 0.6030 - val_accuracy: 0.7581
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.5271 - accuracy: 0.7829 - val_loss: 0.5839 - val_accuracy: 0.7685
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.5148 - accuracy: 0.7901 - val_loss: 0.5949 - val_accuracy: 0.7692
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.4871 - accuracy: 0.8017 - val_loss: 0.5941 - val_accuracy: 0.7629
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.4670 - accuracy: 0.8119 - val_loss: 0.5888 - val_accuracy: 0.7644
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.4595 - accuracy: 0.8147 - val_loss: 0.6251 - val_accuracy: 0.7560
#
# legjobb val_acc:
# 0.7691522240638733
# a modell hiperparaméterei:
# 256
# 256
# 512
# 0.3609152343685501
# 0.15189704405428855
# 0.4020693551700181
# leakyrelu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 1s - loss: 1.0114 - accuracy: 0.5931 - val_loss: 0.8006 - val_accuracy: 0.6529
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.8297 - accuracy: 0.6562 - val_loss: 0.7430 - val_accuracy: 0.6907
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7489 - accuracy: 0.6884 - val_loss: 0.6915 - val_accuracy: 0.7101
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.7020 - accuracy: 0.7067 - val_loss: 0.6710 - val_accuracy: 0.7297
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6713 - accuracy: 0.7201 - val_loss: 0.6409 - val_accuracy: 0.7365
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6440 - accuracy: 0.7342 - val_loss: 0.6390 - val_accuracy: 0.7354
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.6267 - accuracy: 0.7413 - val_loss: 0.6391 - val_accuracy: 0.7409
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.6071 - accuracy: 0.7500 - val_loss: 0.6561 - val_accuracy: 0.7366
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.5930 - accuracy: 0.7529 - val_loss: 0.6694 - val_accuracy: 0.7319
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.5865 - accuracy: 0.7602 - val_loss: 0.6310 - val_accuracy: 0.7399
#
# legjobb val_acc:
# 0.7408920526504517
# a modell hiperparaméterei:
# 128
# 256
# 512
# 0.4373890378874796
# 0.2905665641676321
# 0.45689121548525197
# relu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 0s - loss: 1.1635 - accuracy: 0.5088 - val_loss: 0.8770 - val_accuracy: 0.5758
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.9466 - accuracy: 0.5977 - val_loss: 0.7500 - val_accuracy: 0.6931
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.8279 - accuracy: 0.6483 - val_loss: 0.6949 - val_accuracy: 0.7108
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.7650 - accuracy: 0.6779 - val_loss: 0.6728 - val_accuracy: 0.7128
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.7214 - accuracy: 0.6943 - val_loss: 0.6622 - val_accuracy: 0.7210
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6915 - accuracy: 0.7132 - val_loss: 0.6552 - val_accuracy: 0.7251
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.6672 - accuracy: 0.7205 - val_loss: 0.6575 - val_accuracy: 0.7234
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.6504 - accuracy: 0.7308 - val_loss: 0.6515 - val_accuracy: 0.7319
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.6252 - accuracy: 0.7411 - val_loss: 0.6372 - val_accuracy: 0.7368
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.6173 - accuracy: 0.7475 - val_loss: 0.6375 - val_accuracy: 0.7385
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.6009 - accuracy: 0.7513 - val_loss: 0.6204 - val_accuracy: 0.7421
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.5883 - accuracy: 0.7584 - val_loss: 0.6288 - val_accuracy: 0.7441
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.5845 - accuracy: 0.7615 - val_loss: 0.6264 - val_accuracy: 0.7455
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.5664 - accuracy: 0.7700 - val_loss: 0.6202 - val_accuracy: 0.7523
#
# Epoch 15/100
# 54/54 - 0s - loss: 0.5588 - accuracy: 0.7719 - val_loss: 0.6130 - val_accuracy: 0.7528
#
# Epoch 16/100
# 54/54 - 0s - loss: 0.5501 - accuracy: 0.7768 - val_loss: 0.6179 - val_accuracy: 0.7503
#
# Epoch 17/100
# 54/54 - 0s - loss: 0.5423 - accuracy: 0.7816 - val_loss: 0.6091 - val_accuracy: 0.7535
#
# Epoch 18/100
# 54/54 - 0s - loss: 0.5292 - accuracy: 0.7858 - val_loss: 0.6194 - val_accuracy: 0.7514
#
# Epoch 19/100
# 54/54 - 0s - loss: 0.5242 - accuracy: 0.7885 - val_loss: 0.6208 - val_accuracy: 0.7542
#
# Epoch 20/100
# 54/54 - 0s - loss: 0.5128 - accuracy: 0.7913 - val_loss: 0.6274 - val_accuracy: 0.7520
#
# Epoch 21/100
# 54/54 - 0s - loss: 0.5034 - accuracy: 0.7945 - val_loss: 0.6185 - val_accuracy: 0.7612
#
# Epoch 22/100
# 54/54 - 0s - loss: 0.4949 - accuracy: 0.7999 - val_loss: 0.6057 - val_accuracy: 0.7632
#
# Epoch 23/100
# 54/54 - 0s - loss: 0.4889 - accuracy: 0.7996 - val_loss: 0.6075 - val_accuracy: 0.7618
#
# Epoch 24/100
# 54/54 - 0s - loss: 0.4871 - accuracy: 0.8018 - val_loss: 0.6234 - val_accuracy: 0.7572
#
# Epoch 25/100
# 54/54 - 0s - loss: 0.4732 - accuracy: 0.8110 - val_loss: 0.6084 - val_accuracy: 0.7630
#
# legjobb val_acc:
# 0.7631937265396118
# a modell hiperparaméterei:
# 512
# 256
# 512
# 0.4573438615779279
# 0.3712108768435438
# 0.4975555238793953
# relu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 1s - loss: 1.1170 - accuracy: 0.5464 - val_loss: 0.8394 - val_accuracy: 0.6210
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.8940 - accuracy: 0.6299 - val_loss: 0.6947 - val_accuracy: 0.7096
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7745 - accuracy: 0.6805 - val_loss: 0.6416 - val_accuracy: 0.7312
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.7041 - accuracy: 0.7084 - val_loss: 0.6276 - val_accuracy: 0.7358
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6551 - accuracy: 0.7279 - val_loss: 0.6357 - val_accuracy: 0.7363
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6276 - accuracy: 0.7400 - val_loss: 0.6035 - val_accuracy: 0.7431
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.5984 - accuracy: 0.7488 - val_loss: 0.6059 - val_accuracy: 0.7479
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.5704 - accuracy: 0.7650 - val_loss: 0.6065 - val_accuracy: 0.7479
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.5455 - accuracy: 0.7775 - val_loss: 0.6065 - val_accuracy: 0.7521
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.5343 - accuracy: 0.7827 - val_loss: 0.6053 - val_accuracy: 0.7511
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.5144 - accuracy: 0.7870 - val_loss: 0.6043 - val_accuracy: 0.7569
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.4965 - accuracy: 0.7981 - val_loss: 0.6112 - val_accuracy: 0.7583
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.4813 - accuracy: 0.8041 - val_loss: 0.5914 - val_accuracy: 0.7586
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.4681 - accuracy: 0.8125 - val_loss: 0.5929 - val_accuracy: 0.7603
#
# Epoch 15/100
# 54/54 - 0s - loss: 0.4487 - accuracy: 0.8200 - val_loss: 0.5974 - val_accuracy: 0.7656
#
# Epoch 16/100
# 54/54 - 0s - loss: 0.4274 - accuracy: 0.8293 - val_loss: 0.6332 - val_accuracy: 0.7521
#
# Epoch 17/100
# 54/54 - 0s - loss: 0.4228 - accuracy: 0.8276 - val_loss: 0.6158 - val_accuracy: 0.7555
#
# Epoch 18/100
# 54/54 - 0s - loss: 0.4064 - accuracy: 0.8336 - val_loss: 0.6239 - val_accuracy: 0.7630
#
# legjobb val_acc:
# 0.7655771374702454
# a modell hiperparaméterei:
# 256
# 256
# 512
# 0.4987050743144522
# 0.23260261139877167
# 0.4521193426387564
# leakyrelu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 1s - loss: 1.0703 - accuracy: 0.5575 - val_loss: 0.7693 - val_accuracy: 0.6714
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.8763 - accuracy: 0.6389 - val_loss: 0.7105 - val_accuracy: 0.7053
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7880 - accuracy: 0.6702 - val_loss: 0.6928 - val_accuracy: 0.7181
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.7399 - accuracy: 0.6896 - val_loss: 0.6689 - val_accuracy: 0.7194
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.7066 - accuracy: 0.7067 - val_loss: 0.6577 - val_accuracy: 0.7295
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6728 - accuracy: 0.7203 - val_loss: 0.6642 - val_accuracy: 0.7320
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.6582 - accuracy: 0.7278 - val_loss: 0.6469 - val_accuracy: 0.7343
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.6413 - accuracy: 0.7313 - val_loss: 0.6683 - val_accuracy: 0.7266
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.6315 - accuracy: 0.7375 - val_loss: 0.6456 - val_accuracy: 0.7365
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.6203 - accuracy: 0.7461 - val_loss: 0.6378 - val_accuracy: 0.7438
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.6072 - accuracy: 0.7509 - val_loss: 0.6306 - val_accuracy: 0.7417
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.6005 - accuracy: 0.7507 - val_loss: 0.6507 - val_accuracy: 0.7336
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.5963 - accuracy: 0.7562 - val_loss: 0.6301 - val_accuracy: 0.7412
#
# legjobb val_acc:
# 0.7437861561775208
# a modell hiperparaméterei:
# 512
# 512
# 512
# 0.4047292098464045
# 0.44595615696283164
# 0.340943604834277
# swish
# rmsprop
# 256
#  47%|████▋     | 47/100 [10:26<08:13,  9.30s/it, best loss: -0.7725570201873779]WARNING:tensorflow:AutoGraph could not transform <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f832a363f28>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f832a363f28>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f832a363f28>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f832a363f28>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/100
# 54/54 - 1s - loss: 1.0520 - accuracy: 0.5939 - val_loss: 0.8269 - val_accuracy: 0.6558
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.8477 - accuracy: 0.6565 - val_loss: 0.7630 - val_accuracy: 0.6774
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7701 - accuracy: 0.6814 - val_loss: 0.7328 - val_accuracy: 0.7080
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.7179 - accuracy: 0.7027 - val_loss: 0.6947 - val_accuracy: 0.7126
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6780 - accuracy: 0.7186 - val_loss: 0.7155 - val_accuracy: 0.7116
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6600 - accuracy: 0.7267 - val_loss: 0.6801 - val_accuracy: 0.7327
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.6392 - accuracy: 0.7344 - val_loss: 0.6587 - val_accuracy: 0.7305
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.6265 - accuracy: 0.7387 - val_loss: 0.6548 - val_accuracy: 0.7329
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.6088 - accuracy: 0.7471 - val_loss: 0.6197 - val_accuracy: 0.7457
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.6022 - accuracy: 0.7456 - val_loss: 0.6542 - val_accuracy: 0.7382
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.5905 - accuracy: 0.7556 - val_loss: 0.6397 - val_accuracy: 0.7469
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.5812 - accuracy: 0.7595 - val_loss: 0.6510 - val_accuracy: 0.7377
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.5704 - accuracy: 0.7586 - val_loss: 0.6231 - val_accuracy: 0.7496
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.5597 - accuracy: 0.7670 - val_loss: 0.6436 - val_accuracy: 0.7431
#
# Epoch 15/100
# 54/54 - 0s - loss: 0.5474 - accuracy: 0.7699 - val_loss: 0.6218 - val_accuracy: 0.7550
#
# Epoch 16/100
# 54/54 - 0s - loss: 0.5398 - accuracy: 0.7748 - val_loss: 0.6332 - val_accuracy: 0.7503
#
# Epoch 17/100
# 54/54 - 0s - loss: 0.5233 - accuracy: 0.7812 - val_loss: 0.6327 - val_accuracy: 0.7503
#
# Epoch 18/100
# 54/54 - 0s - loss: 0.5184 - accuracy: 0.7874 - val_loss: 0.6337 - val_accuracy: 0.7531
#
# legjobb val_acc:
# 0.7550221085548401
# a modell hiperparaméterei:
# 256
# 256
# 256
# 0.42000701852926675
# 0.2015570569284601
# 0.4106743919539956
# relu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 0s - loss: 1.1084 - accuracy: 0.5304 - val_loss: 0.8232 - val_accuracy: 0.6190
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.8752 - accuracy: 0.6285 - val_loss: 0.7061 - val_accuracy: 0.7028
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7635 - accuracy: 0.6795 - val_loss: 0.6407 - val_accuracy: 0.7280
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.7039 - accuracy: 0.7074 - val_loss: 0.6332 - val_accuracy: 0.7315
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6659 - accuracy: 0.7224 - val_loss: 0.6209 - val_accuracy: 0.7346
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6358 - accuracy: 0.7321 - val_loss: 0.6223 - val_accuracy: 0.7426
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.6079 - accuracy: 0.7475 - val_loss: 0.6072 - val_accuracy: 0.7455
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.5805 - accuracy: 0.7586 - val_loss: 0.6098 - val_accuracy: 0.7479
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.5669 - accuracy: 0.7684 - val_loss: 0.6031 - val_accuracy: 0.7506
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.5472 - accuracy: 0.7788 - val_loss: 0.6061 - val_accuracy: 0.7521
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.5322 - accuracy: 0.7838 - val_loss: 0.5936 - val_accuracy: 0.7588
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.5226 - accuracy: 0.7888 - val_loss: 0.5928 - val_accuracy: 0.7615
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.5094 - accuracy: 0.7929 - val_loss: 0.5866 - val_accuracy: 0.7606
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.4940 - accuracy: 0.7995 - val_loss: 0.5977 - val_accuracy: 0.7634
#
# Epoch 15/100
# 54/54 - 0s - loss: 0.4768 - accuracy: 0.8064 - val_loss: 0.5976 - val_accuracy: 0.7642
#
# Epoch 16/100
# 54/54 - 0s - loss: 0.4701 - accuracy: 0.8077 - val_loss: 0.5995 - val_accuracy: 0.7657
#
# Epoch 17/100
# 54/54 - 0s - loss: 0.4495 - accuracy: 0.8161 - val_loss: 0.6110 - val_accuracy: 0.7593
#
# Epoch 18/100
# 54/54 - 0s - loss: 0.4384 - accuracy: 0.8226 - val_loss: 0.5996 - val_accuracy: 0.7635
#
# Epoch 19/100
# 54/54 - 0s - loss: 0.4365 - accuracy: 0.8247 - val_loss: 0.6005 - val_accuracy: 0.7625
#
# legjobb val_acc:
# 0.7657473683357239
# a modell hiperparaméterei:
# 128
# 256
# 512
# 0.3611009518751694
# 0.17597246227940389
# 0.35584077371887085
# leakyrelu
# sgd
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.1273 - accuracy: 0.5000 - val_loss: 0.8210 - val_accuracy: 0.6496
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.9594 - accuracy: 0.5717 - val_loss: 0.7885 - val_accuracy: 0.6587
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.8837 - accuracy: 0.6042 - val_loss: 0.7709 - val_accuracy: 0.6660
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.8497 - accuracy: 0.6260 - val_loss: 0.7555 - val_accuracy: 0.6753
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.8113 - accuracy: 0.6471 - val_loss: 0.7411 - val_accuracy: 0.6876
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.7940 - accuracy: 0.6534 - val_loss: 0.7319 - val_accuracy: 0.6914
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.7816 - accuracy: 0.6620 - val_loss: 0.7187 - val_accuracy: 0.6995
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.7644 - accuracy: 0.6660 - val_loss: 0.7181 - val_accuracy: 0.6995
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.7516 - accuracy: 0.6804 - val_loss: 0.7102 - val_accuracy: 0.7014
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.7473 - accuracy: 0.6819 - val_loss: 0.7037 - val_accuracy: 0.7074
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.7387 - accuracy: 0.6870 - val_loss: 0.7011 - val_accuracy: 0.7062
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.7290 - accuracy: 0.6862 - val_loss: 0.6979 - val_accuracy: 0.7108
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.7225 - accuracy: 0.6962 - val_loss: 0.6926 - val_accuracy: 0.7133
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.7187 - accuracy: 0.6959 - val_loss: 0.6897 - val_accuracy: 0.7143
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.7183 - accuracy: 0.6941 - val_loss: 0.6874 - val_accuracy: 0.7113
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.7120 - accuracy: 0.7000 - val_loss: 0.6838 - val_accuracy: 0.7147
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.7033 - accuracy: 0.7059 - val_loss: 0.6842 - val_accuracy: 0.7138
#
# Epoch 18/100
# ...
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.5637 - accuracy: 0.7700 - val_loss: 0.5937 - val_accuracy: 0.7545
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.5545 - accuracy: 0.7731 - val_loss: 0.5990 - val_accuracy: 0.7564
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.5419 - accuracy: 0.7831 - val_loss: 0.5959 - val_accuracy: 0.7557
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.5320 - accuracy: 0.7815 - val_loss: 0.5956 - val_accuracy: 0.7579
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.5265 - accuracy: 0.7842 - val_loss: 0.5990 - val_accuracy: 0.7576
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.5165 - accuracy: 0.7901 - val_loss: 0.5994 - val_accuracy: 0.7571
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.5058 - accuracy: 0.7956 - val_loss: 0.5963 - val_accuracy: 0.7637
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.5049 - accuracy: 0.7966 - val_loss: 0.6005 - val_accuracy: 0.7629
#
# Epoch 20/100
# 215/215 - 1s - loss: 0.4958 - accuracy: 0.8007 - val_loss: 0.5986 - val_accuracy: 0.7603
#
# Epoch 21/100
# 215/215 - 1s - loss: 0.4838 - accuracy: 0.8049 - val_loss: 0.5973 - val_accuracy: 0.7605
#
# legjobb val_acc:
# 0.7637044787406921
# a modell hiperparaméterei:
# 512
# 256
# 512
# 0.3664939424033275
# 0.29874687739611283
# 0.24113081309063236
# relu
# sgd
# 128
# Epoch 1/100
# 108/108 - 1s - loss: 1.2628 - accuracy: 0.4396 - val_loss: 0.9334 - val_accuracy: 0.5909
#
# Epoch 2/100
# 108/108 - 1s - loss: 1.0624 - accuracy: 0.5246 - val_loss: 0.8832 - val_accuracy: 0.6040
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.9835 - accuracy: 0.5575 - val_loss: 0.8483 - val_accuracy: 0.6229
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.9186 - accuracy: 0.5853 - val_loss: 0.8233 - val_accuracy: 0.6340
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.8925 - accuracy: 0.6023 - val_loss: 0.8021 - val_accuracy: 0.6466
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.8522 - accuracy: 0.6272 - val_loss: 0.7817 - val_accuracy: 0.6609
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.8352 - accuracy: 0.6364 - val_loss: 0.7664 - val_accuracy: 0.6680
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.8146 - accuracy: 0.6412 - val_loss: 0.7621 - val_accuracy: 0.6701
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.8008 - accuracy: 0.6501 - val_loss: 0.7496 - val_accuracy: 0.6796
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.7831 - accuracy: 0.6609 - val_loss: 0.7478 - val_accuracy: 0.6750
#
# Epoch 11/100
# 108/108 - 1s - loss: 0.7634 - accuracy: 0.6717 - val_loss: 0.7288 - val_accuracy: 0.6925
#
# Epoch 12/100
# 108/108 - 1s - loss: 0.7517 - accuracy: 0.6781 - val_loss: 0.7179 - val_accuracy: 0.7005
#
# Epoch 13/100
# 108/108 - 1s - loss: 0.7435 - accuracy: 0.6773 - val_loss: 0.7250 - val_accuracy: 0.6905
#
# Epoch 14/100
# 108/108 - 1s - loss: 0.7353 - accuracy: 0.6795 - val_loss: 0.7143 - val_accuracy: 0.6987
#
# Epoch 15/100
# 108/108 - 1s - loss: 0.7255 - accuracy: 0.6911 - val_loss: 0.7126 - val_accuracy: 0.6966
#
# legjobb val_acc:
# 0.7005447745323181
# a modell hiperparaméterei:
# 512
# 256
# 128
# 0.38307978251820873
# 0.12470693715276804
# 0.4660354997850798
# leakyrelu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 1s - loss: 0.9518 - accuracy: 0.6069 - val_loss: 0.7330 - val_accuracy: 0.6925
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.7868 - accuracy: 0.6738 - val_loss: 0.6993 - val_accuracy: 0.7137
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7075 - accuracy: 0.7087 - val_loss: 0.6511 - val_accuracy: 0.7314
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.6771 - accuracy: 0.7204 - val_loss: 0.6386 - val_accuracy: 0.7358
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6459 - accuracy: 0.7312 - val_loss: 0.6314 - val_accuracy: 0.7378
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6234 - accuracy: 0.7443 - val_loss: 0.6357 - val_accuracy: 0.7387
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.6073 - accuracy: 0.7471 - val_loss: 0.6356 - val_accuracy: 0.7375
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.5878 - accuracy: 0.7567 - val_loss: 0.6043 - val_accuracy: 0.7518
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.5651 - accuracy: 0.7666 - val_loss: 0.6128 - val_accuracy: 0.7474
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.5554 - accuracy: 0.7699 - val_loss: 0.5988 - val_accuracy: 0.7572
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.5481 - accuracy: 0.7741 - val_loss: 0.6162 - val_accuracy: 0.7445
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.5416 - accuracy: 0.7748 - val_loss: 0.6102 - val_accuracy: 0.7523
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.5277 - accuracy: 0.7838 - val_loss: 0.6378 - val_accuracy: 0.7421
#
# legjobb val_acc:
# 0.7572352886199951
# a modell hiperparaméterei:
# 256
# 128
# 256
# 0.12214315741002874
# 0.3409572057393548
# 0.4991927786506462
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.0493 - accuracy: 0.5613 - val_loss: 0.7223 - val_accuracy: 0.6953
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7759 - accuracy: 0.6746 - val_loss: 0.6525 - val_accuracy: 0.7244
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.6793 - accuracy: 0.7167 - val_loss: 0.6339 - val_accuracy: 0.7326
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6363 - accuracy: 0.7364 - val_loss: 0.6156 - val_accuracy: 0.7443
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.5922 - accuracy: 0.7569 - val_loss: 0.6113 - val_accuracy: 0.7472
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.5720 - accuracy: 0.7653 - val_loss: 0.6027 - val_accuracy: 0.7538
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5434 - accuracy: 0.7767 - val_loss: 0.6038 - val_accuracy: 0.7520
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.5113 - accuracy: 0.7908 - val_loss: 0.6030 - val_accuracy: 0.7497
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.4921 - accuracy: 0.7955 - val_loss: 0.6079 - val_accuracy: 0.7499
#
# legjobb val_acc:
# 0.7538304328918457
# a modell hiperparaméterei:
# 512
# 256
# 512
# 0.48716243313291624
# 0.0980826054973884
# 0.4558923208803464
# swish
# rmsprop
# 128
#  95%|█████████▌| 95/100 [23:10<01:05, 13.04s/it, best loss: -0.7725570201873779]WARNING:tensorflow:AutoGraph could not transform <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82f388e1d0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82f388e1d0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82f388e1d0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82f388e1d0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/100
# 108/108 - 1s - loss: 1.0074 - accuracy: 0.6036 - val_loss: 0.7827 - val_accuracy: 0.6827
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.8159 - accuracy: 0.6666 - val_loss: 0.8128 - val_accuracy: 0.6820
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.7408 - accuracy: 0.6915 - val_loss: 0.7926 - val_accuracy: 0.6942
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.6935 - accuracy: 0.7151 - val_loss: 0.7169 - val_accuracy: 0.7099
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.6644 - accuracy: 0.7237 - val_loss: 0.6711 - val_accuracy: 0.7280
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.6424 - accuracy: 0.7326 - val_loss: 0.6751 - val_accuracy: 0.7268
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.6273 - accuracy: 0.7391 - val_loss: 0.7084 - val_accuracy: 0.7198
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.6127 - accuracy: 0.7425 - val_loss: 0.6729 - val_accuracy: 0.7215
#
# legjobb val_acc:
# 0.7279536724090576
# a modell hiperparaméterei:
# 512
# 512
# 128
# 0.28855631788626596
# 0.2729658035678629
# 0.16359750892120667
# relu
# adam
# 256
# Epoch 1/100
# 54/54 - 0s - loss: 0.9964 - accuracy: 0.5891 - val_loss: 0.7952 - val_accuracy: 0.6529
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.7524 - accuracy: 0.6859 - val_loss: 0.6838 - val_accuracy: 0.7135
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.6689 - accuracy: 0.7232 - val_loss: 0.6330 - val_accuracy: 0.7368
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.6087 - accuracy: 0.7491 - val_loss: 0.5980 - val_accuracy: 0.7537
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.5606 - accuracy: 0.7706 - val_loss: 0.5965 - val_accuracy: 0.7508
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.5304 - accuracy: 0.7847 - val_loss: 0.6024 - val_accuracy: 0.7557
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.4970 - accuracy: 0.7965 - val_loss: 0.6014 - val_accuracy: 0.7559
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.4728 - accuracy: 0.8101 - val_loss: 0.5904 - val_accuracy: 0.7601
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.4457 - accuracy: 0.8192 - val_loss: 0.5979 - val_accuracy: 0.7623
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.4127 - accuracy: 0.8337 - val_loss: 0.6152 - val_accuracy: 0.7605
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.4017 - accuracy: 0.8365 - val_loss: 0.6081 - val_accuracy: 0.7642
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.3736 - accuracy: 0.8493 - val_loss: 0.6222 - val_accuracy: 0.7610
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.3493 - accuracy: 0.8588 - val_loss: 0.6478 - val_accuracy: 0.7601
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.3242 - accuracy: 0.8706 - val_loss: 0.6524 - val_accuracy: 0.7630
#
# legjobb val_acc:
# 0.7642151713371277
# a modell hiperparaméterei:
# 128
# 128
# 256
# 0.46303924687856757
# 0.18671336803942767
# 0.37042506998886293
# relu
# rmsprop
# 128
# Epoch 1/100
# 108/108 - 1s - loss: 1.1418 - accuracy: 0.5030 - val_loss: 0.8104 - val_accuracy: 0.6513
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.9018 - accuracy: 0.6090 - val_loss: 0.7105 - val_accuracy: 0.6975
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.7906 - accuracy: 0.6609 - val_loss: 0.6767 - val_accuracy: 0.7102
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.7335 - accuracy: 0.6861 - val_loss: 0.6649 - val_accuracy: 0.7172
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.6990 - accuracy: 0.7062 - val_loss: 0.6591 - val_accuracy: 0.7247
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.6744 - accuracy: 0.7163 - val_loss: 0.6384 - val_accuracy: 0.7310
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.6489 - accuracy: 0.7264 - val_loss: 0.6357 - val_accuracy: 0.7344
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.6378 - accuracy: 0.7356 - val_loss: 0.6436 - val_accuracy: 0.7348
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.6207 - accuracy: 0.7440 - val_loss: 0.6106 - val_accuracy: 0.7453
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.6063 - accuracy: 0.7502 - val_loss: 0.6091 - val_accuracy: 0.7463
#
# Epoch 11/100
# 108/108 - 1s - loss: 0.5973 - accuracy: 0.7529 - val_loss: 0.6173 - val_accuracy: 0.7428
#
# Epoch 12/100
# 108/108 - 1s - loss: 0.5870 - accuracy: 0.7579 - val_loss: 0.6000 - val_accuracy: 0.7497
#
# Epoch 13/100
# 108/108 - 1s - loss: 0.5709 - accuracy: 0.7659 - val_loss: 0.6067 - val_accuracy: 0.7457
#
# Epoch 14/100
# 108/108 - 1s - loss: 0.5639 - accuracy: 0.7667 - val_loss: 0.6060 - val_accuracy: 0.7489
#
# Epoch 15/100
# 108/108 - 1s - loss: 0.5548 - accuracy: 0.7705 - val_loss: 0.6011 - val_accuracy: 0.7538
#
# Epoch 16/100
# 108/108 - 1s - loss: 0.5412 - accuracy: 0.7802 - val_loss: 0.6091 - val_accuracy: 0.7470
#
# Epoch 17/100
# 108/108 - 1s - loss: 0.5436 - accuracy: 0.7771 - val_loss: 0.6042 - val_accuracy: 0.7537
#
# Epoch 18/100
# 108/108 - 1s - loss: 0.5308 - accuracy: 0.7843 - val_loss: 0.5998 - val_accuracy: 0.7531
#
# legjobb val_acc:
# 0.7538304328918457
# a modell hiperparaméterei:
# 512
# 256
# 512
# 0.3528170337846399
# 0.3202521736192322
# 0.4492978498407167
# relu
# sgd
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.2430 - accuracy: 0.4552 - val_loss: 0.8652 - val_accuracy: 0.6188
#
# Epoch 2/100
# 215/215 - 1s - loss: 1.0005 - accuracy: 0.5472 - val_loss: 0.8208 - val_accuracy: 0.6342
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.9070 - accuracy: 0.5895 - val_loss: 0.7878 - val_accuracy: 0.6537
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.8424 - accuracy: 0.6255 - val_loss: 0.7599 - val_accuracy: 0.6701
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.8150 - accuracy: 0.6417 - val_loss: 0.7450 - val_accuracy: 0.6765
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.7914 - accuracy: 0.6586 - val_loss: 0.7335 - val_accuracy: 0.6825
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.7764 - accuracy: 0.6616 - val_loss: 0.7223 - val_accuracy: 0.6915
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.7549 - accuracy: 0.6742 - val_loss: 0.7069 - val_accuracy: 0.7005
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.7395 - accuracy: 0.6802 - val_loss: 0.7008 - val_accuracy: 0.7007
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.7279 - accuracy: 0.6915 - val_loss: 0.6900 - val_accuracy: 0.7048
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.7192 - accuracy: 0.6914 - val_loss: 0.6842 - val_accuracy: 0.7079
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.7095 - accuracy: 0.6972 - val_loss: 0.6827 - val_accuracy: 0.7062
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.6980 - accuracy: 0.7045 - val_loss: 0.6757 - val_accuracy: 0.7099
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.6897 - accuracy: 0.7052 - val_loss: 0.6743 - val_accuracy: 0.7125
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.6857 - accuracy: 0.7120 - val_loss: 0.6698 - val_accuracy: 0.7128
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.6678 - accuracy: 0.7186 - val_loss: 0.6662 - val_accuracy: 0.7162
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.6692 - accuracy: 0.7177 - val_loss: 0.6598 - val_accuracy: 0.7223
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.6640 - accuracy: 0.7224 - val_loss: 0.6547 - val_accuracy: 0.7220
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.6545 - accuracy: 0.7271 - val_loss: 0.6526 - val_accuracy: 0.7240
#
# Epoch 20/100
# 215/215 - 1s - loss: 0.6432 - accuracy: 0.7319 - val_loss: 0.6549 - val_accuracy: 0.7211
#
# Epoch 21/100
# 215/215 - 1s - loss: 0.6448 - accuracy: 0.7294 - val_loss: 0.6479 - val_accuracy: 0.7240
#
# Epoch 22/100
# 215/215 - 1s - loss: 0.6354 - accuracy: 0.7337 - val_loss: 0.6411 - val_accuracy: 0.7264
#
# Epoch 23/100
# 215/215 - 1s - loss: 0.6325 - accuracy: 0.7362 - val_loss: 0.6386 - val_accuracy: 0.7315
#
# Epoch 24/100
# 215/215 - 1s - loss: 0.6273 - accuracy: 0.7405 - val_loss: 0.6377 - val_accuracy: 0.7286
#
# Epoch 25/100
# 215/215 - 1s - loss: 0.6272 - accuracy: 0.7343 - val_loss: 0.6320 - val_accuracy: 0.7302
#
# Epoch 26/100
# 215/215 - 1s - loss: 0.6160 - accuracy: 0.7403 - val_loss: 0.6332 - val_accuracy: 0.7308
#
# legjobb val_acc:
# 0.7315287590026855
# a modell hiperparaméterei:
# 512
# 256
# 128
# 0.44039891171639056
# 0.08322444152459117
# 0.38872407804740866
# leakyrelu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 1s - loss: 0.9726 - accuracy: 0.5967 - val_loss: 0.7230 - val_accuracy: 0.6963
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.7938 - accuracy: 0.6721 - val_loss: 0.7027 - val_accuracy: 0.7097
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7207 - accuracy: 0.6984 - val_loss: 0.6664 - val_accuracy: 0.7269
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.6839 - accuracy: 0.7192 - val_loss: 0.6707 - val_accuracy: 0.7322
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6493 - accuracy: 0.7286 - val_loss: 0.6337 - val_accuracy: 0.7406
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6289 - accuracy: 0.7420 - val_loss: 0.6395 - val_accuracy: 0.7416
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.6125 - accuracy: 0.7456 - val_loss: 0.6346 - val_accuracy: 0.7402
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.5928 - accuracy: 0.7524 - val_loss: 0.6176 - val_accuracy: 0.7533
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.5772 - accuracy: 0.7636 - val_loss: 0.6321 - val_accuracy: 0.7419
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.5689 - accuracy: 0.7669 - val_loss: 0.6060 - val_accuracy: 0.7509
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.5545 - accuracy: 0.7699 - val_loss: 0.6200 - val_accuracy: 0.7465
#
# legjobb val_acc:
# 0.7533197402954102
# 100%|██████████| 100/100 [24:16<00:00, 14.56s/it, best loss: -0.7725570201873779]

# %%
x_train, y_train, x_test, y_test = data()
print("best model evaluation:")
print(best_model.evaluate(x_test, y_test))
print("best hyperparameters:")
print(best_run)
# Out:
# legjobb modell kiértékelése:
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6009 - accuracy: 0.7640
# [0.6009337902069092, 0.7640449404716492]
# legjobb hiperparaméterek:
# {'act': 0, 'dropout_1': 0.3593433530010136, 'dropout_1_1': 0.21880463535340797, 'dropout_1_2': 0.4911238980854753, 'n_batch': 1, 'n_layer1': 2, 'n_layer1_1': 0, 'n_layer1_2': 0, 'optim': 1}

# %%
best_model.save('hyperparam1_best_model.h5')

# %% [markdown]
# The best model of this hyperparamer optimalization giving an accuracy of 76.40%, which is our best result.

# %% [markdown]
# ### Hyperparameter optimalization with GloVe
# We can download the GloVe vectors:http://www-nlp.stanford.edu/data/glove.840B.300d.zip

# %%
from tqdm import tqdm

# %%
# load the GloVe vectors in a dictionary:

embeddings_index = {}
f = open('/content/drive/MyDrive/Author_identification/glove.840B.300d.txt')
for line in tqdm(f):
  values = line.split()
  word = values[0]
  # Catch the exception where there are strings in the Glove text file.
  try:
      coefs = np.asarray(values[1:], dtype='float32')
      embeddings_index[word] = coefs
  except ValueError:
      pass
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# 2196017it [03:08, 11665.90it/s]
# Found 2195884 word vectors.

# %%
# this function creates a normalized vector for the whole sentence
def sent2vec(s):
    words = str(s).lower()#.decode('utf-8')
    words = word_tokenize(words)
    words = [w for w in words if w.isalpha()]
    M = []
    for w in words:
        try:
            M.append(embeddings_index[w])
        except:
            continue
    M = np.array(M)
    v = M.sum(axis=0)
    if type(v) != np.ndarray:
        return np.zeros(300)
    return v / np.sqrt((v ** 2).sum())

# %%
# create sentence vectors using the above function for training and validation set
xtrain_glove = [sent2vec(x) for x in tqdm(X_ws_train)]
xvalid_glove = [sent2vec(x) for x in tqdm(X_ws_valid)]
# Out:
# 100%|██████████| 13705/13705 [00:02<00:00, 4590.93it/s]
# 100%|██████████| 5874/5874 [00:01<00:00, 4590.93it/s]

# %%
xtrain_glove = np.array(xtrain_glove)
xvalid_glove = np.array(xvalid_glove)

# %%
from sklearn.preprocessing import StandardScaler

# %%
# scale the data before any neural net:
scl = StandardScaler()
xtrain_glove_scl = scl.fit_transform(xtrain_glove)
xvalid_glove_scl = scl.transform(xvalid_glove)

# %%
with open('dataset2.npy', 'wb') as f:
    np.save(f, xtrain_glove_scl)
    np.save(f, y_ws_train_list)
    np.save(f, xvalid_glove_scl)
    np.save(f, y_ws_valid_list)

with open('dataset2.npy', 'rb') as f:
    X_train = np.load(f)
    y_train = np.load(f)
    X_valid = np.load(f)
    y_valid = np.load(f)

# %%
def data2():
  with open('dataset2.npy', 'rb') as f:
    x_train = np.load(f)
    y_train = np.load(f)
    x_test = np.load(f)
    y_test = np.load(f)
  
  return x_train, y_train, x_test, y_test

# %%
def create_model2(x_train, y_train, x_test, y_test):
    from keras.layers import Layer
    from keras import backend as K

    class Swish(Layer):
        def __init__(self, beta, **kwargs):
            super(Swish, self).__init__(**kwargs)
            self.beta = K.cast_to_floatx(beta)

        def call(self, inputs):
            return K.sigmoid(self.beta * inputs) * inputs

        def get_config(self):
            config = {'beta': float(self.beta)}
            base_config = super(Swish, self).get_config()
            return dict(list(base_config.items()) + list(config.items()))

        def compute_output_shape(self, input_shape):
            return input_shape
    # swish end
    
    # our hyperparameters
    n_layer1 = {{choice([128, 256, 512])}}
    n_layer2 = {{choice([128, 256, 512])}}
    n_layer3 = {{choice([128, 256, 512])}}
    dropout_1 = {{uniform(0, 0.5)}}
    dropout_2 = {{uniform(0, 0.5)}}
    dropout_3 = {{uniform(0, 0.5)}}
    act = {{choice(['relu', 'leakyrelu', 'swish'])}}
    optim = {{choice(['rmsprop', 'adam', 'sgd'])}}
    n_batch = {{choice([64, 128, 256])}}
    print('a modell hiperparaméterei: ', n_layer1, n_layer2, n_layer3, dropout_1, dropout_2, dropout_3, act, optim, n_batch)

    if act == 'relu':
        activation = keras.layers.ReLU()
    elif act == 'leakyrelu':
        activation = keras.layers.LeakyReLU()
    elif act == 'swish':
        activation = Swish(beta=0.3)
    
    model = Sequential()
    model.add(Dense(n_layer1, input_dim=300))
    model.add(activation)
    model.add(Dropout(dropout_1))
    model.add(BatchNormalization())

    model.add(Dense(n_layer2))
    model.add(activation)
    model.add(Dropout(dropout_2))
    model.add(BatchNormalization())

    model.add(Dense(n_layer3))
    model.add(activation)
    model.add(Dropout(dropout_3))
    model.add(BatchNormalization())

    model.add(Dense(3, activation='softmax'))
    
    model.compile(optimizer=optim,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    callbacks = [EarlyStopping(monitor='val_accuracy', patience=3, verbose=0)]
    
    result = model.fit(x_train, y_train,
              batch_size=n_batch,
              epochs=100,
              verbose=2,
              validation_data=(x_test, y_test),
              callbacks=callbacks,
              shuffle=True)

    best_val_acc = np.amax(result.history['val_accuracy']) 
    print('legjobb val_acc:', best_val_acc)

    with open('hyperopt-log.csv', 'a') as csv_file:
      csv_file.write(str(n_layer1) + ';')
      csv_file.write(str(n_layer2) + ';')
      csv_file.write(str(n_layer3) + ';')
      csv_file.write(str(dropout_1) + ';')
      csv_file.write(str(dropout_2) + ';')
      csv_file.write(str(dropout_3) + ';')
      csv_file.write(str(act) + ';')
      csv_file.write(str(optim) + ';')
      csv_file.write(str(n_batch) + ';')
      csv_file.write(str(best_val_acc) + '\n')

    return {'loss': -best_val_acc, 'status': STATUS_OK, 'model': model}

# %%
with open('hyperopt-log.csv', 'w') as csv_file:
  csv_file.write('n_layer1' + ';')
  csv_file.write('n_layer2' + ';')
  csv_file.write('n_layer3' + ';')
  csv_file.write('dropout_1' + ';')
  csv_file.write('dropout_2' + ';')
  csv_file.write('dropout_3' + ';')
  csv_file.write('act' + ';')
  csv_file.write('optim' + ';')
  csv_file.write('n_batch' + ';')
  csv_file.write('best_val_acc' + '\n')

# %% [markdown]
# # Notebook download and upload to colab

# %%
# !pip3 install hyperas
# !pip3 install hyperopt

# %%
import hyperas
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

# %%
best_run, best_model = optim.minimize(model=create_model2,
                                          data=data2,
                                          algo=tpe.suggest,
                                          max_evals=100,
                                          notebook_name='Hyperparameter_optimalization',
                                          trials=Trials())
# Out:
# A streamkimeneten csak az utolsó 5000 sor látható.
# 128
# 0.4892838288723406
# 0.22720001177701898
# 0.032150814859929766
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9904 - accuracy: 0.5668 - val_loss: 0.7423 - val_accuracy: 0.6869
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7981 - accuracy: 0.6544 - val_loss: 0.6964 - val_accuracy: 0.7036
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.7247 - accuracy: 0.6920 - val_loss: 0.6693 - val_accuracy: 0.7193
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6906 - accuracy: 0.7089 - val_loss: 0.6641 - val_accuracy: 0.7206
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6692 - accuracy: 0.7184 - val_loss: 0.6454 - val_accuracy: 0.7276
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.6494 - accuracy: 0.7316 - val_loss: 0.6366 - val_accuracy: 0.7329
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.6249 - accuracy: 0.7380 - val_loss: 0.6287 - val_accuracy: 0.7377
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.6137 - accuracy: 0.7480 - val_loss: 0.6192 - val_accuracy: 0.7450
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.6011 - accuracy: 0.7532 - val_loss: 0.6162 - val_accuracy: 0.7443
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.5828 - accuracy: 0.7598 - val_loss: 0.6023 - val_accuracy: 0.7504
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.5723 - accuracy: 0.7660 - val_loss: 0.6154 - val_accuracy: 0.7486
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.5530 - accuracy: 0.7744 - val_loss: 0.6131 - val_accuracy: 0.7487
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.5503 - accuracy: 0.7738 - val_loss: 0.6073 - val_accuracy: 0.7501
#
# legjobb val_acc:
# 0.7504255771636963
# a modell hiperparaméterei:
# 256
# 256
# 256
# 0.2688609014037103
# 0.33494040742131526
# 0.1308314298031113
# relu
# sgd
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.1406 - accuracy: 0.4929 - val_loss: 0.8497 - val_accuracy: 0.6287
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.9501 - accuracy: 0.5730 - val_loss: 0.8003 - val_accuracy: 0.6537
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.8766 - accuracy: 0.6091 - val_loss: 0.7674 - val_accuracy: 0.6716
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.8383 - accuracy: 0.6313 - val_loss: 0.7517 - val_accuracy: 0.6803
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.8024 - accuracy: 0.6458 - val_loss: 0.7359 - val_accuracy: 0.6912
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.7865 - accuracy: 0.6567 - val_loss: 0.7259 - val_accuracy: 0.6944
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.7636 - accuracy: 0.6712 - val_loss: 0.7143 - val_accuracy: 0.6990
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.7467 - accuracy: 0.6814 - val_loss: 0.7053 - val_accuracy: 0.7017
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.7348 - accuracy: 0.6819 - val_loss: 0.6964 - val_accuracy: 0.7063
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.7251 - accuracy: 0.6902 - val_loss: 0.6922 - val_accuracy: 0.7063
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.7167 - accuracy: 0.6920 - val_loss: 0.6876 - val_accuracy: 0.7104
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.7059 - accuracy: 0.7006 - val_loss: 0.6811 - val_accuracy: 0.7116
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.6962 - accuracy: 0.7043 - val_loss: 0.6740 - val_accuracy: 0.7138
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.6949 - accuracy: 0.7048 - val_loss: 0.6727 - val_accuracy: 0.7159
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.6826 - accuracy: 0.7127 - val_loss: 0.6656 - val_accuracy: 0.7191
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.6773 - accuracy: 0.7115 - val_loss: 0.6633 - val_accuracy: 0.7179
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.6681 - accuracy: 0.7145 - val_loss: 0.6628 - val_accuracy: 0.7196
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.6615 - accuracy: 0.7211 - val_loss: 0.6601 - val_accuracy: 0.7208
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.6583 - accuracy: 0.7237 - val_loss: 0.6566 - val_accuracy: 0.7208
#
# Epoch 20/100
# 215/215 - 1s - loss: 0.6480 - accuracy: 0.7332 - val_loss: 0.6528 - val_accuracy: 0.7278
#
# Epoch 21/100
# 215/215 - 1s - loss: 0.6521 - accuracy: 0.7263 - val_loss: 0.6489 - val_accuracy: 0.7256
#
# Epoch 22/100
# 215/215 - 1s - loss: 0.6373 - accuracy: 0.7305 - val_loss: 0.6469 - val_accuracy: 0.7291
#
# Epoch 23/100
# 215/215 - 1s - loss: 0.6377 - accuracy: 0.7305 - val_loss: 0.6419 - val_accuracy: 0.7305
#
# Epoch 24/100
# 215/215 - 1s - loss: 0.6370 - accuracy: 0.7329 - val_loss: 0.6407 - val_accuracy: 0.7314
#
# Epoch 25/100
# 215/215 - 1s - loss: 0.6245 - accuracy: 0.7368 - val_loss: 0.6434 - val_accuracy: 0.7297
#
# Epoch 26/100
# 215/215 - 1s - loss: 0.6181 - accuracy: 0.7416 - val_loss: 0.6412 - val_accuracy: 0.7331
#
# Epoch 27/100
# 215/215 - 1s - loss: 0.6239 - accuracy: 0.7405 - val_loss: 0.6358 - val_accuracy: 0.7326
#
# Epoch 28/100
# 215/215 - 1s - loss: 0.6120 - accuracy: 0.7478 - val_loss: 0.6343 - val_accuracy: 0.7344
#
# Epoch 29/100
# 215/215 - 1s - loss: 0.6091 - accuracy: 0.7468 - val_loss: 0.6314 - val_accuracy: 0.7368
#
# Epoch 30/100
# 215/215 - 1s - loss: 0.6042 - accuracy: 0.7490 - val_loss: 0.6359 - val_accuracy: 0.7353
#
# Epoch 31/100
# 215/215 - 1s - loss: 0.6018 - accuracy: 0.7538 - val_loss: 0.6283 - val_accuracy: 0.7387
#
# Epoch 32/100
# 215/215 - 1s - loss: 0.5947 - accuracy: 0.7529 - val_loss: 0.6273 - val_accuracy: 0.7394
#
# Epoch 33/100
# 215/215 - 1s - loss: 0.5906 - accuracy: 0.7564 - val_loss: 0.6291 - val_accuracy: 0.7368
#
# Epoch 34/100
# 215/215 - 1s - loss: 0.5892 - accuracy: 0.7545 - val_loss: 0.6285 - val_accuracy: 0.7395
#
# Epoch 35/100
# 215/215 - 1s - loss: 0.5874 - accuracy: 0.7553 - val_loss: 0.6272 - val_accuracy: 0.7385
#
# Epoch 36/100
# 215/215 - 1s - loss: 0.5790 - accuracy: 0.7586 - val_loss: 0.6279 - val_accuracy: 0.7382
#
# Epoch 37/100
# 215/215 - 1s - loss: 0.5788 - accuracy: 0.7637 - val_loss: 0.6243 - val_accuracy: 0.7411
#
# Epoch 38/100
# 215/215 - 1s - loss: 0.5730 - accuracy: 0.7652 - val_loss: 0.6260 - val_accuracy: 0.7402
#
# Epoch 39/100
# 215/215 - 1s - loss: 0.5661 - accuracy: 0.7688 - val_loss: 0.6255 - val_accuracy: 0.7395
#
# Epoch 40/100
# 215/215 - 1s - loss: 0.5693 - accuracy: 0.7651 - val_loss: 0.6247 - val_accuracy: 0.7400
#
# legjobb val_acc:
# 0.7410622835159302
# a modell hiperparaméterei:
# 256
# 256
# 128
# 0.31923162278649647
# 0.16362963437924102
# 0.24430720346829793
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9939 - accuracy: 0.5803 - val_loss: 0.7176 - val_accuracy: 0.7000
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7741 - accuracy: 0.6699 - val_loss: 0.6636 - val_accuracy: 0.7259
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.6983 - accuracy: 0.7042 - val_loss: 0.6408 - val_accuracy: 0.7286
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6502 - accuracy: 0.7322 - val_loss: 0.6271 - val_accuracy: 0.7341
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6191 - accuracy: 0.7425 - val_loss: 0.6154 - val_accuracy: 0.7406
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.5885 - accuracy: 0.7554 - val_loss: 0.6050 - val_accuracy: 0.7482
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5703 - accuracy: 0.7641 - val_loss: 0.6007 - val_accuracy: 0.7491
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.5505 - accuracy: 0.7721 - val_loss: 0.6007 - val_accuracy: 0.7499
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.5345 - accuracy: 0.7834 - val_loss: 0.6015 - val_accuracy: 0.7533
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.5137 - accuracy: 0.7915 - val_loss: 0.5993 - val_accuracy: 0.7598
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.5021 - accuracy: 0.7925 - val_loss: 0.5985 - val_accuracy: 0.7559
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.4835 - accuracy: 0.8013 - val_loss: 0.6040 - val_accuracy: 0.7542
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.4684 - accuracy: 0.8103 - val_loss: 0.6149 - val_accuracy: 0.7521
#
# legjobb val_acc:
# 0.7597888708114624
# a modell hiperparaméterei:
# 256
# 256
# 256
# 0.425933934260284
# 0.0855533464573029
# 0.13941784158026452
# relu
# sgd
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.1623 - accuracy: 0.4854 - val_loss: 0.8520 - val_accuracy: 0.6200
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.9580 - accuracy: 0.5701 - val_loss: 0.8197 - val_accuracy: 0.6369
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.8923 - accuracy: 0.5977 - val_loss: 0.7778 - val_accuracy: 0.6612
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.8510 - accuracy: 0.6238 - val_loss: 0.7563 - val_accuracy: 0.6757
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.8215 - accuracy: 0.6437 - val_loss: 0.7424 - val_accuracy: 0.6805
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.7950 - accuracy: 0.6505 - val_loss: 0.7359 - val_accuracy: 0.6849
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.7781 - accuracy: 0.6581 - val_loss: 0.7206 - val_accuracy: 0.6896
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.7588 - accuracy: 0.6741 - val_loss: 0.7133 - val_accuracy: 0.6937
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.7546 - accuracy: 0.6776 - val_loss: 0.7098 - val_accuracy: 0.6975
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.7362 - accuracy: 0.6855 - val_loss: 0.7003 - val_accuracy: 0.7000
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.7349 - accuracy: 0.6841 - val_loss: 0.6987 - val_accuracy: 0.7000
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.7232 - accuracy: 0.6879 - val_loss: 0.6945 - val_accuracy: 0.7029
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.7159 - accuracy: 0.6972 - val_loss: 0.6813 - val_accuracy: 0.7104
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.7083 - accuracy: 0.6954 - val_loss: 0.6796 - val_accuracy: 0.7077
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.6992 - accuracy: 0.7014 - val_loss: 0.6772 - val_accuracy: 0.7108
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.6917 - accuracy: 0.7060 - val_loss: 0.6727 - val_accuracy: 0.7126
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.6932 - accuracy: 0.7063 - val_loss: 0.6711 - val_accuracy: 0.7140
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.6868 - accuracy: 0.7060 - val_loss: 0.6710 - val_accuracy: 0.7148
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.6737 - accuracy: 0.7159 - val_loss: 0.6657 - val_accuracy: 0.7165
#
# Epoch 20/100
# 215/215 - 1s - loss: 0.6727 - accuracy: 0.7148 - val_loss: 0.6621 - val_accuracy: 0.7198
#
# Epoch 21/100
# 215/215 - 1s - loss: 0.6694 - accuracy: 0.7160 - val_loss: 0.6603 - val_accuracy: 0.7167
#
# Epoch 22/100
# 215/215 - 1s - loss: 0.6613 - accuracy: 0.7209 - val_loss: 0.6571 - val_accuracy: 0.7208
#
# Epoch 23/100
# 215/215 - 1s - loss: 0.6572 - accuracy: 0.7222 - val_loss: 0.6573 - val_accuracy: 0.7196
#
# Epoch 24/100
# 215/215 - 1s - loss: 0.6548 - accuracy: 0.7290 - val_loss: 0.6568 - val_accuracy: 0.7217
#
# Epoch 25/100
# 215/215 - 1s - loss: 0.6545 - accuracy: 0.7260 - val_loss: 0.6535 - val_accuracy: 0.7249
#
# Epoch 26/100
# 215/215 - 1s - loss: 0.6436 - accuracy: 0.7339 - val_loss: 0.6507 - val_accuracy: 0.7259
#
# Epoch 27/100
# 215/215 - 1s - loss: 0.6351 - accuracy: 0.7323 - val_loss: 0.6548 - val_accuracy: 0.7244
#
# Epoch 28/100
# 215/215 - 1s - loss: 0.6436 - accuracy: 0.7295 - val_loss: 0.6467 - val_accuracy: 0.7261
#
# Epoch 29/100
# 215/215 - 1s - loss: 0.6364 - accuracy: 0.7332 - val_loss: 0.6463 - val_accuracy: 0.7271
#
# Epoch 30/100
# 215/215 - 1s - loss: 0.6286 - accuracy: 0.7372 - val_loss: 0.6453 - val_accuracy: 0.7281
#
# Epoch 31/100
# 215/215 - 1s - loss: 0.6226 - accuracy: 0.7367 - val_loss: 0.6374 - val_accuracy: 0.7322
#
# Epoch 32/100
# 215/215 - 1s - loss: 0.6212 - accuracy: 0.7384 - val_loss: 0.6469 - val_accuracy: 0.7259
#
# Epoch 33/100
# 215/215 - 1s - loss: 0.6159 - accuracy: 0.7450 - val_loss: 0.6367 - val_accuracy: 0.7329
#
# Epoch 34/100
# 215/215 - 1s - loss: 0.6065 - accuracy: 0.7475 - val_loss: 0.6362 - val_accuracy: 0.7331
#
# Epoch 35/100
# 215/215 - 1s - loss: 0.6119 - accuracy: 0.7466 - val_loss: 0.6371 - val_accuracy: 0.7332
#
# Epoch 36/100
# 215/215 - 1s - loss: 0.6034 - accuracy: 0.7471 - val_loss: 0.6328 - val_accuracy: 0.7349
#
# Epoch 37/100
# 215/215 - 1s - loss: 0.6019 - accuracy: 0.7532 - val_loss: 0.6329 - val_accuracy: 0.7351
#
# Epoch 38/100
# 215/215 - 1s - loss: 0.5976 - accuracy: 0.7513 - val_loss: 0.6342 - val_accuracy: 0.7344
#
# Epoch 39/100
# 215/215 - 1s - loss: 0.5984 - accuracy: 0.7536 - val_loss: 0.6317 - val_accuracy: 0.7360
#
# Epoch 40/100
# 215/215 - 1s - loss: 0.5950 - accuracy: 0.7556 - val_loss: 0.6312 - val_accuracy: 0.7368
#
# Epoch 41/100
# 215/215 - 1s - loss: 0.5898 - accuracy: 0.7551 - val_loss: 0.6331 - val_accuracy: 0.7368
#
# Epoch 42/100
# 215/215 - 1s - loss: 0.5935 - accuracy: 0.7530 - val_loss: 0.6323 - val_accuracy: 0.7356
#
# Epoch 43/100
# 215/215 - 1s - loss: 0.5839 - accuracy: 0.7602 - val_loss: 0.6304 - val_accuracy: 0.7373
#
# Epoch 44/100
# 215/215 - 1s - loss: 0.5826 - accuracy: 0.7605 - val_loss: 0.6314 - val_accuracy: 0.7375
#
# Epoch 45/100
# 215/215 - 1s - loss: 0.5772 - accuracy: 0.7637 - val_loss: 0.6315 - val_accuracy: 0.7361
#
# Epoch 46/100
# 215/215 - 1s - loss: 0.5779 - accuracy: 0.7576 - val_loss: 0.6300 - val_accuracy: 0.7390
#
# Epoch 47/100
# 215/215 - 1s - loss: 0.5750 - accuracy: 0.7629 - val_loss: 0.6304 - val_accuracy: 0.7366
#
# Epoch 48/100
# 215/215 - 1s - loss: 0.5760 - accuracy: 0.7605 - val_loss: 0.6263 - val_accuracy: 0.7380
#
# Epoch 49/100
# 215/215 - 1s - loss: 0.5676 - accuracy: 0.7670 - val_loss: 0.6316 - val_accuracy: 0.7382
#
# legjobb val_acc:
# 0.7390193939208984
# a modell hiperparaméterei:
# 256
# 256
# 128
# 0.18518283954458983
# 0.003693289648570325
# 0.08773251656189814
# relu
# rmsprop
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9041 - accuracy: 0.6176 - val_loss: 0.7192 - val_accuracy: 0.6925
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.6877 - accuracy: 0.7100 - val_loss: 0.6886 - val_accuracy: 0.7108
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.6088 - accuracy: 0.7472 - val_loss: 0.6652 - val_accuracy: 0.7213
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.5547 - accuracy: 0.7737 - val_loss: 0.6424 - val_accuracy: 0.7402
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.5064 - accuracy: 0.7926 - val_loss: 0.6366 - val_accuracy: 0.7460
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.4743 - accuracy: 0.8109 - val_loss: 0.6531 - val_accuracy: 0.7344
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.4309 - accuracy: 0.8284 - val_loss: 0.6715 - val_accuracy: 0.7388
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.3920 - accuracy: 0.8443 - val_loss: 0.6810 - val_accuracy: 0.7419
#
# legjobb val_acc:
# 0.7459993362426758
# a modell hiperparaméterei:
# 256
# 128
# 256
# 0.47226100311647734
# 0.2921353302429849
# 0.2979827041644516
# relu
# rmsprop
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.0588 - accuracy: 0.5386 - val_loss: 0.7405 - val_accuracy: 0.6782
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.8260 - accuracy: 0.6434 - val_loss: 0.6842 - val_accuracy: 0.7080
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.7445 - accuracy: 0.6846 - val_loss: 0.6667 - val_accuracy: 0.7186
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6947 - accuracy: 0.7095 - val_loss: 0.6618 - val_accuracy: 0.7247
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6637 - accuracy: 0.7211 - val_loss: 0.6509 - val_accuracy: 0.7273
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.6394 - accuracy: 0.7355 - val_loss: 0.6359 - val_accuracy: 0.7377
#
# Epoch 7/100
# 215/215 - 2s - loss: 0.6231 - accuracy: 0.7443 - val_loss: 0.6263 - val_accuracy: 0.7450
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.5997 - accuracy: 0.7557 - val_loss: 0.6141 - val_accuracy: 0.7455
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.5825 - accuracy: 0.7596 - val_loss: 0.6302 - val_accuracy: 0.7421
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.5765 - accuracy: 0.7694 - val_loss: 0.6324 - val_accuracy: 0.7407
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.5550 - accuracy: 0.7756 - val_loss: 0.6067 - val_accuracy: 0.7457
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.5531 - accuracy: 0.7763 - val_loss: 0.6052 - val_accuracy: 0.7533
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.5376 - accuracy: 0.7855 - val_loss: 0.6202 - val_accuracy: 0.7451
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.5305 - accuracy: 0.7827 - val_loss: 0.6006 - val_accuracy: 0.7537
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.5146 - accuracy: 0.7905 - val_loss: 0.6078 - val_accuracy: 0.7480
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.5079 - accuracy: 0.7982 - val_loss: 0.6122 - val_accuracy: 0.7577
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.4918 - accuracy: 0.7999 - val_loss: 0.6104 - val_accuracy: 0.7489
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.4880 - accuracy: 0.8061 - val_loss: 0.6030 - val_accuracy: 0.7528
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.4777 - accuracy: 0.8082 - val_loss: 0.6044 - val_accuracy: 0.7562
#
# legjobb val_acc:
# 0.7577459812164307
# a modell hiperparaméterei:
# 256
# 256
# 128
# 0.3157937373876303
# 0.4599139836094549
# 0.4308043028174291
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.0578 - accuracy: 0.5441 - val_loss: 0.7374 - val_accuracy: 0.6793
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.8042 - accuracy: 0.6567 - val_loss: 0.6800 - val_accuracy: 0.7094
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.7167 - accuracy: 0.6988 - val_loss: 0.6482 - val_accuracy: 0.7276
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6783 - accuracy: 0.7172 - val_loss: 0.6369 - val_accuracy: 0.7356
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6504 - accuracy: 0.7327 - val_loss: 0.6236 - val_accuracy: 0.7421
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.6280 - accuracy: 0.7440 - val_loss: 0.6160 - val_accuracy: 0.7434
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.6065 - accuracy: 0.7543 - val_loss: 0.6182 - val_accuracy: 0.7419
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.5845 - accuracy: 0.7626 - val_loss: 0.6055 - val_accuracy: 0.7463
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.5654 - accuracy: 0.7676 - val_loss: 0.5998 - val_accuracy: 0.7506
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.5617 - accuracy: 0.7721 - val_loss: 0.6031 - val_accuracy: 0.7531
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.5326 - accuracy: 0.7833 - val_loss: 0.6109 - val_accuracy: 0.7491
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.5235 - accuracy: 0.7883 - val_loss: 0.6179 - val_accuracy: 0.7450
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.5078 - accuracy: 0.7959 - val_loss: 0.6016 - val_accuracy: 0.7538
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.4948 - accuracy: 0.7980 - val_loss: 0.6010 - val_accuracy: 0.7499
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.4846 - accuracy: 0.8069 - val_loss: 0.6000 - val_accuracy: 0.7566
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.4596 - accuracy: 0.8147 - val_loss: 0.6032 - val_accuracy: 0.7576
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.4526 - accuracy: 0.8182 - val_loss: 0.6063 - val_accuracy: 0.7514
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.4381 - accuracy: 0.8256 - val_loss: 0.6158 - val_accuracy: 0.7572
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.4305 - accuracy: 0.8296 - val_loss: 0.6071 - val_accuracy: 0.7594
#
# Epoch 20/100
# 215/215 - 1s - loss: 0.4340 - accuracy: 0.8251 - val_loss: 0.6181 - val_accuracy: 0.7596
#
# Epoch 21/100
# 215/215 - 1s - loss: 0.4247 - accuracy: 0.8319 - val_loss: 0.6126 - val_accuracy: 0.7571
#
# Epoch 22/100
# 215/215 - 1s - loss: 0.4047 - accuracy: 0.8375 - val_loss: 0.6150 - val_accuracy: 0.7651
#
# Epoch 23/100
# 215/215 - 1s - loss: 0.4028 - accuracy: 0.8423 - val_loss: 0.6200 - val_accuracy: 0.7562
#
# Epoch 24/100
# 215/215 - 1s - loss: 0.3833 - accuracy: 0.8463 - val_loss: 0.6329 - val_accuracy: 0.7554
#
# Epoch 25/100
# 215/215 - 1s - loss: 0.3673 - accuracy: 0.8579 - val_loss: 0.6409 - val_accuracy: 0.7487
#
# legjobb val_acc:
# 0.765066385269165
# a modell hiperparaméterei:
# 128
# 256
# 256
# 0.2390560815399265
# 0.4740465531787827
# 0.4263664014096994
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.0736 - accuracy: 0.5383 - val_loss: 0.7537 - val_accuracy: 0.6738
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.8283 - accuracy: 0.6428 - val_loss: 0.7075 - val_accuracy: 0.7021
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.7420 - accuracy: 0.6854 - val_loss: 0.6777 - val_accuracy: 0.7133
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6910 - accuracy: 0.7121 - val_loss: 0.6498 - val_accuracy: 0.7227
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6696 - accuracy: 0.7197 - val_loss: 0.6414 - val_accuracy: 0.7319
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.6387 - accuracy: 0.7324 - val_loss: 0.6233 - val_accuracy: 0.7388
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.6142 - accuracy: 0.7457 - val_loss: 0.6211 - val_accuracy: 0.7429
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.6008 - accuracy: 0.7508 - val_loss: 0.6153 - val_accuracy: 0.7423
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.5838 - accuracy: 0.7586 - val_loss: 0.6083 - val_accuracy: 0.7455
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.5707 - accuracy: 0.7611 - val_loss: 0.6055 - val_accuracy: 0.7470
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.5469 - accuracy: 0.7778 - val_loss: 0.6122 - val_accuracy: 0.7460
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.5325 - accuracy: 0.7831 - val_loss: 0.6059 - val_accuracy: 0.7491
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.5348 - accuracy: 0.7830 - val_loss: 0.6033 - val_accuracy: 0.7501
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.5158 - accuracy: 0.7920 - val_loss: 0.6072 - val_accuracy: 0.7440
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.4994 - accuracy: 0.7988 - val_loss: 0.6201 - val_accuracy: 0.7429
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.4848 - accuracy: 0.8066 - val_loss: 0.6139 - val_accuracy: 0.7460
#
# legjobb val_acc:
# 0.7500851154327393
# a modell hiperparaméterei:
# 512
# 256
# 256
# 0.1763133893320586
# 0.44870385227243537
# 0.27149286435800285
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9619 - accuracy: 0.5964 - val_loss: 0.6974 - val_accuracy: 0.7068
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7270 - accuracy: 0.6951 - val_loss: 0.6543 - val_accuracy: 0.7251
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.6589 - accuracy: 0.7278 - val_loss: 0.6437 - val_accuracy: 0.7390
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6037 - accuracy: 0.7481 - val_loss: 0.6236 - val_accuracy: 0.7446
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.5739 - accuracy: 0.7672 - val_loss: 0.6027 - val_accuracy: 0.7511
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.5385 - accuracy: 0.7800 - val_loss: 0.6025 - val_accuracy: 0.7516
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5102 - accuracy: 0.7936 - val_loss: 0.6034 - val_accuracy: 0.7530
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.4855 - accuracy: 0.8038 - val_loss: 0.6163 - val_accuracy: 0.7520
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.4573 - accuracy: 0.8171 - val_loss: 0.6052 - val_accuracy: 0.7540
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.4283 - accuracy: 0.8266 - val_loss: 0.6238 - val_accuracy: 0.7591
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.4021 - accuracy: 0.8403 - val_loss: 0.6313 - val_accuracy: 0.7516
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.3828 - accuracy: 0.8492 - val_loss: 0.6590 - val_accuracy: 0.7566
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.3871 - accuracy: 0.8430 - val_loss: 0.6450 - val_accuracy: 0.7520
#
# legjobb val_acc:
# 0.7591079473495483
# a modell hiperparaméterei:
# 256
# 256
# 128
# 0.31551309408679196
# 0.3314679036191449
# 0.4456233840302337
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.0442 - accuracy: 0.5578 - val_loss: 0.7233 - val_accuracy: 0.6915
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.8074 - accuracy: 0.6530 - val_loss: 0.6725 - val_accuracy: 0.7160
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.7237 - accuracy: 0.6937 - val_loss: 0.6516 - val_accuracy: 0.7237
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6775 - accuracy: 0.7185 - val_loss: 0.6380 - val_accuracy: 0.7356
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6412 - accuracy: 0.7376 - val_loss: 0.6218 - val_accuracy: 0.7383
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.6233 - accuracy: 0.7413 - val_loss: 0.6194 - val_accuracy: 0.7443
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5951 - accuracy: 0.7553 - val_loss: 0.6104 - val_accuracy: 0.7434
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.5759 - accuracy: 0.7655 - val_loss: 0.6111 - val_accuracy: 0.7443
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.5592 - accuracy: 0.7723 - val_loss: 0.6033 - val_accuracy: 0.7460
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.5434 - accuracy: 0.7772 - val_loss: 0.5948 - val_accuracy: 0.7503
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.5297 - accuracy: 0.7796 - val_loss: 0.5944 - val_accuracy: 0.7612
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.5075 - accuracy: 0.7950 - val_loss: 0.5945 - val_accuracy: 0.7554
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.4924 - accuracy: 0.8006 - val_loss: 0.6029 - val_accuracy: 0.7550
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.4821 - accuracy: 0.8067 - val_loss: 0.6075 - val_accuracy: 0.7545
#
# legjobb val_acc:
# 0.7611508369445801
# a modell hiperparaméterei:
# 256
# 128
# 256
# 0.009696278775131184
# 0.35958514554191084
# 0.4941475713713274
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9937 - accuracy: 0.5821 - val_loss: 0.7046 - val_accuracy: 0.7041
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7423 - accuracy: 0.6847 - val_loss: 0.6590 - val_accuracy: 0.7228
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.6627 - accuracy: 0.7235 - val_loss: 0.6305 - val_accuracy: 0.7343
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6077 - accuracy: 0.7543 - val_loss: 0.6177 - val_accuracy: 0.7467
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.5662 - accuracy: 0.7678 - val_loss: 0.6190 - val_accuracy: 0.7417
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.5482 - accuracy: 0.7767 - val_loss: 0.6199 - val_accuracy: 0.7409
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5051 - accuracy: 0.7985 - val_loss: 0.6277 - val_accuracy: 0.7409
#
# legjobb val_acc:
# 0.7466802597045898
# a modell hiperparaméterei:
# 512
# 256
# 128
# 0.361610492782565
# 0.24877984881325604
# 0.21363445635575204
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9557 - accuracy: 0.5999 - val_loss: 0.7000 - val_accuracy: 0.7067
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7434 - accuracy: 0.6822 - val_loss: 0.6506 - val_accuracy: 0.7269
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.6730 - accuracy: 0.7173 - val_loss: 0.6368 - val_accuracy: 0.7361
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6298 - accuracy: 0.7368 - val_loss: 0.6197 - val_accuracy: 0.7417
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6025 - accuracy: 0.7522 - val_loss: 0.6140 - val_accuracy: 0.7458
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.5743 - accuracy: 0.7634 - val_loss: 0.6071 - val_accuracy: 0.7521
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5493 - accuracy: 0.7731 - val_loss: 0.5994 - val_accuracy: 0.7504
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.5225 - accuracy: 0.7883 - val_loss: 0.6023 - val_accuracy: 0.7572
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.5093 - accuracy: 0.7924 - val_loss: 0.5999 - val_accuracy: 0.7564
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.4903 - accuracy: 0.8021 - val_loss: 0.5974 - val_accuracy: 0.7577
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.4764 - accuracy: 0.8085 - val_loss: 0.5943 - val_accuracy: 0.7569
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.4458 - accuracy: 0.8212 - val_loss: 0.6083 - val_accuracy: 0.7562
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.4429 - accuracy: 0.8217 - val_loss: 0.5935 - val_accuracy: 0.7625
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.4153 - accuracy: 0.8336 - val_loss: 0.6181 - val_accuracy: 0.7564
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.4083 - accuracy: 0.8339 - val_loss: 0.6132 - val_accuracy: 0.7554
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.4012 - accuracy: 0.8392 - val_loss: 0.6195 - val_accuracy: 0.7629
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.3778 - accuracy: 0.8511 - val_loss: 0.6238 - val_accuracy: 0.7598
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.3741 - accuracy: 0.8513 - val_loss: 0.6341 - val_accuracy: 0.7567
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.3641 - accuracy: 0.8558 - val_loss: 0.6289 - val_accuracy: 0.7588
#
# legjobb val_acc:
# 0.7628532648086548
# a modell hiperparaméterei:
# 512
# 256
# 128
# 0.35573591097994034
# 0.4451280875150803
# 0.3342329518963738
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9777 - accuracy: 0.5704 - val_loss: 0.7056 - val_accuracy: 0.7039
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7703 - accuracy: 0.6706 - val_loss: 0.6609 - val_accuracy: 0.7205
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.6962 - accuracy: 0.7079 - val_loss: 0.6401 - val_accuracy: 0.7290
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6543 - accuracy: 0.7273 - val_loss: 0.6190 - val_accuracy: 0.7400
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6286 - accuracy: 0.7420 - val_loss: 0.6190 - val_accuracy: 0.7397
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.5949 - accuracy: 0.7602 - val_loss: 0.6057 - val_accuracy: 0.7487
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5735 - accuracy: 0.7648 - val_loss: 0.5984 - val_accuracy: 0.7484
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.5540 - accuracy: 0.7721 - val_loss: 0.6065 - val_accuracy: 0.7479
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.5373 - accuracy: 0.7850 - val_loss: 0.5961 - val_accuracy: 0.7501
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.5173 - accuracy: 0.7880 - val_loss: 0.5924 - val_accuracy: 0.7583
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.5050 - accuracy: 0.7938 - val_loss: 0.5919 - val_accuracy: 0.7530
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.4790 - accuracy: 0.8107 - val_loss: 0.6107 - val_accuracy: 0.7542
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.4636 - accuracy: 0.8166 - val_loss: 0.6045 - val_accuracy: 0.7581
#
# legjobb val_acc:
# 0.758256733417511
# a modell hiperparaméterei:
# 512
# 512
# 128
# 0.29991690707347435
# 0.27880053585581266
# 0.41298317959614056
# relu
# sgd
# 256
# Epoch 1/100
# 54/54 - 0s - loss: 1.3798 - accuracy: 0.4064 - val_loss: 0.9468 - val_accuracy: 0.5737
#
# Epoch 2/100
# 54/54 - 0s - loss: 1.1600 - accuracy: 0.4911 - val_loss: 0.8827 - val_accuracy: 0.6147
#
# Epoch 3/100
# 54/54 - 0s - loss: 1.0781 - accuracy: 0.5313 - val_loss: 0.8488 - val_accuracy: 0.6282
#
# Epoch 4/100
# 54/54 - 0s - loss: 1.0115 - accuracy: 0.5555 - val_loss: 0.8271 - val_accuracy: 0.6359
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.9813 - accuracy: 0.5696 - val_loss: 0.8122 - val_accuracy: 0.6454
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.9397 - accuracy: 0.5883 - val_loss: 0.7989 - val_accuracy: 0.6515
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.9129 - accuracy: 0.5957 - val_loss: 0.7897 - val_accuracy: 0.6566
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.8818 - accuracy: 0.6165 - val_loss: 0.7818 - val_accuracy: 0.6593
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.8719 - accuracy: 0.6177 - val_loss: 0.7736 - val_accuracy: 0.6655
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.8548 - accuracy: 0.6279 - val_loss: 0.7673 - val_accuracy: 0.6677
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.8448 - accuracy: 0.6255 - val_loss: 0.7600 - val_accuracy: 0.6711
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.8365 - accuracy: 0.6387 - val_loss: 0.7558 - val_accuracy: 0.6718
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.8198 - accuracy: 0.6449 - val_loss: 0.7506 - val_accuracy: 0.6748
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.8067 - accuracy: 0.6474 - val_loss: 0.7462 - val_accuracy: 0.6757
#
# Epoch 15/100
# 54/54 - 0s - loss: 0.8046 - accuracy: 0.6505 - val_loss: 0.7418 - val_accuracy: 0.6769
#
# Epoch 16/100
# 54/54 - 0s - loss: 0.7878 - accuracy: 0.6587 - val_loss: 0.7381 - val_accuracy: 0.6786
#
# Epoch 17/100
# 54/54 - 0s - loss: 0.7856 - accuracy: 0.6622 - val_loss: 0.7347 - val_accuracy: 0.6810
#
# Epoch 18/100
# 54/54 - 0s - loss: 0.7782 - accuracy: 0.6638 - val_loss: 0.7323 - val_accuracy: 0.6815
#
# Epoch 19/100
# 54/54 - 0s - loss: 0.7739 - accuracy: 0.6691 - val_loss: 0.7291 - val_accuracy: 0.6830
#
# Epoch 20/100
# 54/54 - 0s - loss: 0.7702 - accuracy: 0.6699 - val_loss: 0.7255 - val_accuracy: 0.6835
#
# Epoch 21/100
# 54/54 - 0s - loss: 0.7604 - accuracy: 0.6733 - val_loss: 0.7220 - val_accuracy: 0.6861
#
# Epoch 22/100
# 54/54 - 0s - loss: 0.7536 - accuracy: 0.6781 - val_loss: 0.7183 - val_accuracy: 0.6883
#
# Epoch 23/100
# 54/54 - 0s - loss: 0.7540 - accuracy: 0.6769 - val_loss: 0.7156 - val_accuracy: 0.6903
#
# Epoch 24/100
# 54/54 - 0s - loss: 0.7474 - accuracy: 0.6793 - val_loss: 0.7131 - val_accuracy: 0.6908
#
# Epoch 25/100
# 54/54 - 0s - loss: 0.7449 - accuracy: 0.6823 - val_loss: 0.7099 - val_accuracy: 0.6927
#
# Epoch 26/100
# 54/54 - 0s - loss: 0.7382 - accuracy: 0.6870 - val_loss: 0.7085 - val_accuracy: 0.6925
#
# Epoch 27/100
# 54/54 - 0s - loss: 0.7326 - accuracy: 0.6876 - val_loss: 0.7062 - val_accuracy: 0.6937
#
# Epoch 28/100
# 54/54 - 0s - loss: 0.7257 - accuracy: 0.6879 - val_loss: 0.7037 - val_accuracy: 0.6946
#
# Epoch 29/100
# 54/54 - 0s - loss: 0.7254 - accuracy: 0.6928 - val_loss: 0.7016 - val_accuracy: 0.6944
#
# Epoch 30/100
# 54/54 - 0s - loss: 0.7258 - accuracy: 0.6916 - val_loss: 0.6993 - val_accuracy: 0.6951
#
# Epoch 31/100
# 54/54 - 0s - loss: 0.7173 - accuracy: 0.6965 - val_loss: 0.6972 - val_accuracy: 0.6956
#
# Epoch 32/100
# 54/54 - 0s - loss: 0.7125 - accuracy: 0.6976 - val_loss: 0.6943 - val_accuracy: 0.6977
#
# Epoch 33/100
# 54/54 - 0s - loss: 0.7086 - accuracy: 0.6966 - val_loss: 0.6930 - val_accuracy: 0.6982
#
# Epoch 34/100
# 54/54 - 0s - loss: 0.7079 - accuracy: 0.7021 - val_loss: 0.6913 - val_accuracy: 0.7000
#
# Epoch 35/100
# 54/54 - 0s - loss: 0.7048 - accuracy: 0.6976 - val_loss: 0.6894 - val_accuracy: 0.7014
#
# Epoch 36/100
# 54/54 - 0s - loss: 0.7013 - accuracy: 0.7005 - val_loss: 0.6877 - val_accuracy: 0.7024
#
# Epoch 37/100
# 54/54 - 0s - loss: 0.6936 - accuracy: 0.7020 - val_loss: 0.6855 - val_accuracy: 0.7036
#
# Epoch 38/100
# 54/54 - 0s - loss: 0.6967 - accuracy: 0.7030 - val_loss: 0.6841 - val_accuracy: 0.7038
#
# Epoch 39/100
# 54/54 - 0s - loss: 0.6924 - accuracy: 0.7082 - val_loss: 0.6819 - val_accuracy: 0.7050
#
# Epoch 40/100
# 54/54 - 0s - loss: 0.6867 - accuracy: 0.7128 - val_loss: 0.6810 - val_accuracy: 0.7051
#
# Epoch 41/100
# 54/54 - 0s - loss: 0.6927 - accuracy: 0.7059 - val_loss: 0.6790 - val_accuracy: 0.7074
#
# Epoch 42/100
# 54/54 - 0s - loss: 0.6859 - accuracy: 0.7095 - val_loss: 0.6773 - val_accuracy: 0.7092
#
# Epoch 43/100
# 54/54 - 0s - loss: 0.6828 - accuracy: 0.7118 - val_loss: 0.6756 - val_accuracy: 0.7109
#
# Epoch 44/100
# 54/54 - 0s - loss: 0.6761 - accuracy: 0.7121 - val_loss: 0.6744 - val_accuracy: 0.7109
#
# Epoch 45/100
# 54/54 - 0s - loss: 0.6816 - accuracy: 0.7135 - val_loss: 0.6726 - val_accuracy: 0.7113
#
# Epoch 46/100
# 54/54 - 0s - loss: 0.6779 - accuracy: 0.7164 - val_loss: 0.6711 - val_accuracy: 0.7118
#
# Epoch 47/100
# 54/54 - 0s - loss: 0.6731 - accuracy: 0.7149 - val_loss: 0.6700 - val_accuracy: 0.7120
#
# Epoch 48/100
# 54/54 - 0s - loss: 0.6749 - accuracy: 0.7136 - val_loss: 0.6680 - val_accuracy: 0.7130
#
# Epoch 49/100
# 54/54 - 0s - loss: 0.6680 - accuracy: 0.7184 - val_loss: 0.6670 - val_accuracy: 0.7143
#
# Epoch 50/100
# 54/54 - 0s - loss: 0.6675 - accuracy: 0.7170 - val_loss: 0.6655 - val_accuracy: 0.7140
#
# Epoch 51/100
# 54/54 - 0s - loss: 0.6666 - accuracy: 0.7207 - val_loss: 0.6635 - val_accuracy: 0.7155
#
# Epoch 52/100
# 54/54 - 0s - loss: 0.6657 - accuracy: 0.7251 - val_loss: 0.6627 - val_accuracy: 0.7165
#
# Epoch 53/100
# 54/54 - 0s - loss: 0.6581 - accuracy: 0.7256 - val_loss: 0.6621 - val_accuracy: 0.7160
#
# Epoch 54/100
# 54/54 - 0s - loss: 0.6593 - accuracy: 0.7256 - val_loss: 0.6612 - val_accuracy: 0.7169
#
# Epoch 55/100
# 54/54 - 0s - loss: 0.6530 - accuracy: 0.7275 - val_loss: 0.6600 - val_accuracy: 0.7176
#
# Epoch 56/100
# 54/54 - 0s - loss: 0.6521 - accuracy: 0.7212 - val_loss: 0.6585 - val_accuracy: 0.7184
#
# Epoch 57/100
# 54/54 - 0s - loss: 0.6533 - accuracy: 0.7277 - val_loss: 0.6581 - val_accuracy: 0.7182
#
# Epoch 58/100
# 54/54 - 0s - loss: 0.6467 - accuracy: 0.7249 - val_loss: 0.6570 - val_accuracy: 0.7177
#
# Epoch 59/100
# 54/54 - 0s - loss: 0.6436 - accuracy: 0.7275 - val_loss: 0.6558 - val_accuracy: 0.7194
#
# Epoch 60/100
# 54/54 - 0s - loss: 0.6433 - accuracy: 0.7321 - val_loss: 0.6549 - val_accuracy: 0.7186
#
# Epoch 61/100
# 54/54 - 0s - loss: 0.6380 - accuracy: 0.7314 - val_loss: 0.6534 - val_accuracy: 0.7196
#
# Epoch 62/100
# 54/54 - 0s - loss: 0.6493 - accuracy: 0.7284 - val_loss: 0.6521 - val_accuracy: 0.7211
#
# Epoch 63/100
# 54/54 - 0s - loss: 0.6399 - accuracy: 0.7308 - val_loss: 0.6511 - val_accuracy: 0.7206
#
# Epoch 64/100
# 54/54 - 0s - loss: 0.6353 - accuracy: 0.7365 - val_loss: 0.6497 - val_accuracy: 0.7196
#
# Epoch 65/100
# 54/54 - 0s - loss: 0.6391 - accuracy: 0.7326 - val_loss: 0.6482 - val_accuracy: 0.7203
#
# legjobb val_acc:
# 0.7211440205574036
# a modell hiperparaméterei:
# 512
# 256
# 128
# 0.2614581930621881
# 0.31980083072731585
# 0.26084065885277846
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9532 - accuracy: 0.5986 - val_loss: 0.6889 - val_accuracy: 0.7121
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7251 - accuracy: 0.6916 - val_loss: 0.6433 - val_accuracy: 0.7320
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.6553 - accuracy: 0.7294 - val_loss: 0.6266 - val_accuracy: 0.7373
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6034 - accuracy: 0.7530 - val_loss: 0.6152 - val_accuracy: 0.7402
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.5718 - accuracy: 0.7648 - val_loss: 0.6071 - val_accuracy: 0.7451
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.5510 - accuracy: 0.7753 - val_loss: 0.6138 - val_accuracy: 0.7414
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5215 - accuracy: 0.7844 - val_loss: 0.6000 - val_accuracy: 0.7566
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.4950 - accuracy: 0.7989 - val_loss: 0.6028 - val_accuracy: 0.7521
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.4660 - accuracy: 0.8145 - val_loss: 0.6224 - val_accuracy: 0.7521
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.4417 - accuracy: 0.8219 - val_loss: 0.6233 - val_accuracy: 0.7509
#
# legjobb val_acc:
# 0.7565543055534363
# a modell hiperparaméterei:
# 512
# 256
# 128
# 0.3552123010914147
# 0.20566911581731895
# 0.4594753483099651
# relu
# adam
# 256
# Epoch 1/100
# 54/54 - 0s - loss: 1.0849 - accuracy: 0.5539 - val_loss: 0.8053 - val_accuracy: 0.6493
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.8283 - accuracy: 0.6568 - val_loss: 0.7029 - val_accuracy: 0.7085
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7375 - accuracy: 0.6914 - val_loss: 0.6558 - val_accuracy: 0.7285
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.6712 - accuracy: 0.7250 - val_loss: 0.6315 - val_accuracy: 0.7375
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6274 - accuracy: 0.7423 - val_loss: 0.6172 - val_accuracy: 0.7440
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.5926 - accuracy: 0.7572 - val_loss: 0.6109 - val_accuracy: 0.7457
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.5652 - accuracy: 0.7680 - val_loss: 0.6078 - val_accuracy: 0.7526
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.5448 - accuracy: 0.7748 - val_loss: 0.6102 - val_accuracy: 0.7535
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.5230 - accuracy: 0.7889 - val_loss: 0.6107 - val_accuracy: 0.7528
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.4988 - accuracy: 0.7972 - val_loss: 0.6046 - val_accuracy: 0.7564
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.4725 - accuracy: 0.8085 - val_loss: 0.6124 - val_accuracy: 0.7526
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.4566 - accuracy: 0.8155 - val_loss: 0.6181 - val_accuracy: 0.7555
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.4354 - accuracy: 0.8259 - val_loss: 0.6124 - val_accuracy: 0.7555
#
# legjobb val_acc:
# 0.7563840746879578
# a modell hiperparaméterei:
# 512
# 512
# 512
# 0.19062424210679244
# 0.4893312766719768
# 0.3405994357256962
# swish
# adam
# 128
#  41%|████      | 41/100 [11:12<13:35, 13.82s/it, best loss: -0.765066385269165]WARNING:tensorflow:AutoGraph could not transform <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f8261305470>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f8261305470>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f8261305470>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f8261305470>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/100
# 108/108 - 1s - loss: 0.9763 - accuracy: 0.6165 - val_loss: 0.7394 - val_accuracy: 0.6978
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.7697 - accuracy: 0.6800 - val_loss: 0.6796 - val_accuracy: 0.7227
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.7095 - accuracy: 0.7022 - val_loss: 0.6640 - val_accuracy: 0.7300
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.6767 - accuracy: 0.7176 - val_loss: 0.6555 - val_accuracy: 0.7310
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.6565 - accuracy: 0.7288 - val_loss: 0.6579 - val_accuracy: 0.7291
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.6451 - accuracy: 0.7345 - val_loss: 0.6450 - val_accuracy: 0.7343
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.6257 - accuracy: 0.7407 - val_loss: 0.6338 - val_accuracy: 0.7431
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.6131 - accuracy: 0.7453 - val_loss: 0.6462 - val_accuracy: 0.7324
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.6045 - accuracy: 0.7499 - val_loss: 0.6485 - val_accuracy: 0.7320
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.5903 - accuracy: 0.7574 - val_loss: 0.6333 - val_accuracy: 0.7385
#
# legjobb val_acc:
# 0.7431052327156067
# a modell hiperparaméterei:
# 512
# 128
# 128
# 0.41936678289566376
# 0.3553363135584019
# 0.28390598716996457
# relu
# sgd
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.2055 - accuracy: 0.4301 - val_loss: 0.8947 - val_accuracy: 0.6093
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.9998 - accuracy: 0.5322 - val_loss: 0.8497 - val_accuracy: 0.6239
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.9206 - accuracy: 0.5804 - val_loss: 0.8205 - val_accuracy: 0.6360
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.8809 - accuracy: 0.6012 - val_loss: 0.8020 - val_accuracy: 0.6473
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.8479 - accuracy: 0.6215 - val_loss: 0.7821 - val_accuracy: 0.6549
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.8258 - accuracy: 0.6366 - val_loss: 0.7651 - val_accuracy: 0.6651
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.8059 - accuracy: 0.6452 - val_loss: 0.7558 - val_accuracy: 0.6670
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.7954 - accuracy: 0.6582 - val_loss: 0.7427 - val_accuracy: 0.6745
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.7834 - accuracy: 0.6625 - val_loss: 0.7325 - val_accuracy: 0.6820
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.7728 - accuracy: 0.6690 - val_loss: 0.7232 - val_accuracy: 0.6859
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.7565 - accuracy: 0.6716 - val_loss: 0.7134 - val_accuracy: 0.6907
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.7486 - accuracy: 0.6753 - val_loss: 0.7069 - val_accuracy: 0.6965
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.7493 - accuracy: 0.6792 - val_loss: 0.7014 - val_accuracy: 0.7007
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.7338 - accuracy: 0.6822 - val_loss: 0.6973 - val_accuracy: 0.7012
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.7304 - accuracy: 0.6880 - val_loss: 0.6919 - val_accuracy: 0.7033
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.7169 - accuracy: 0.6936 - val_loss: 0.6881 - val_accuracy: 0.7043
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.7088 - accuracy: 0.7028 - val_loss: 0.6822 - val_accuracy: 0.7084
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.7105 - accuracy: 0.6990 - val_loss: 0.6783 - val_accuracy: 0.7111
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.6986 - accuracy: 0.7067 - val_loss: 0.6760 - val_accuracy: 0.7108
#
# Epoch 20/100
# 215/215 - 1s - loss: 0.6954 - accuracy: 0.7066 - val_loss: 0.6685 - val_accuracy: 0.7120
#
# Epoch 21/100
# 215/215 - 1s - loss: 0.6919 - accuracy: 0.7098 - val_loss: 0.6650 - val_accuracy: 0.7140
#
# Epoch 22/100
# 215/215 - 1s - loss: 0.6864 - accuracy: 0.7089 - val_loss: 0.6637 - val_accuracy: 0.7157
#
# Epoch 23/100
# 215/215 - 1s - loss: 0.6928 - accuracy: 0.7104 - val_loss: 0.6606 - val_accuracy: 0.7179
#
# Epoch 24/100
# 215/215 - 1s - loss: 0.6719 - accuracy: 0.7181 - val_loss: 0.6569 - val_accuracy: 0.7194
#
# Epoch 25/100
# 215/215 - 1s - loss: 0.6752 - accuracy: 0.7156 - val_loss: 0.6547 - val_accuracy: 0.7198
#
# Epoch 26/100
# 215/215 - 1s - loss: 0.6690 - accuracy: 0.7214 - val_loss: 0.6512 - val_accuracy: 0.7235
#
# Epoch 27/100
# 215/215 - 1s - loss: 0.6624 - accuracy: 0.7242 - val_loss: 0.6496 - val_accuracy: 0.7244
#
# Epoch 28/100
# 215/215 - 1s - loss: 0.6609 - accuracy: 0.7228 - val_loss: 0.6475 - val_accuracy: 0.7256
#
# Epoch 29/100
# 215/215 - 1s - loss: 0.6566 - accuracy: 0.7267 - val_loss: 0.6427 - val_accuracy: 0.7263
#
# Epoch 30/100
# 215/215 - 1s - loss: 0.6498 - accuracy: 0.7295 - val_loss: 0.6421 - val_accuracy: 0.7263
#
# Epoch 31/100
# 215/215 - 1s - loss: 0.6459 - accuracy: 0.7285 - val_loss: 0.6405 - val_accuracy: 0.7276
#
# Epoch 32/100
# 215/215 - 1s - loss: 0.6428 - accuracy: 0.7313 - val_loss: 0.6396 - val_accuracy: 0.7290
#
# Epoch 33/100
# 215/215 - 1s - loss: 0.6394 - accuracy: 0.7353 - val_loss: 0.6399 - val_accuracy: 0.7286
#
# Epoch 34/100
# 215/215 - 1s - loss: 0.6264 - accuracy: 0.7406 - val_loss: 0.6351 - val_accuracy: 0.7329
#
# Epoch 35/100
# 215/215 - 1s - loss: 0.6309 - accuracy: 0.7383 - val_loss: 0.6343 - val_accuracy: 0.7336
#
# Epoch 36/100
# 215/215 - 1s - loss: 0.6276 - accuracy: 0.7394 - val_loss: 0.6341 - val_accuracy: 0.7337
#
# Epoch 37/100
# 215/215 - 1s - loss: 0.6238 - accuracy: 0.7399 - val_loss: 0.6330 - val_accuracy: 0.7349
#
# Epoch 38/100
# 215/215 - 1s - loss: 0.6209 - accuracy: 0.7435 - val_loss: 0.6307 - val_accuracy: 0.7361
#
# Epoch 39/100
# 215/215 - 1s - loss: 0.6150 - accuracy: 0.7470 - val_loss: 0.6287 - val_accuracy: 0.7390
#
# Epoch 40/100
# 215/215 - 1s - loss: 0.6146 - accuracy: 0.7437 - val_loss: 0.6282 - val_accuracy: 0.7385
#
# Epoch 41/100
# 215/215 - 1s - loss: 0.6125 - accuracy: 0.7481 - val_loss: 0.6260 - val_accuracy: 0.7394
#
# Epoch 42/100
# 215/215 - 1s - loss: 0.6037 - accuracy: 0.7507 - val_loss: 0.6255 - val_accuracy: 0.7399
#
# Epoch 43/100
# 215/215 - 1s - loss: 0.6002 - accuracy: 0.7540 - val_loss: 0.6230 - val_accuracy: 0.7402
#
# Epoch 44/100
# 215/215 - 1s - loss: 0.6016 - accuracy: 0.7489 - val_loss: 0.6250 - val_accuracy: 0.7387
#
# Epoch 45/100
# 215/215 - 1s - loss: 0.5966 - accuracy: 0.7542 - val_loss: 0.6221 - val_accuracy: 0.7411
#
# Epoch 46/100
# 215/215 - 1s - loss: 0.5963 - accuracy: 0.7549 - val_loss: 0.6212 - val_accuracy: 0.7419
#
# Epoch 47/100
# 215/215 - 1s - loss: 0.5936 - accuracy: 0.7539 - val_loss: 0.6196 - val_accuracy: 0.7404
#
# Epoch 48/100
# 215/215 - 1s - loss: 0.5888 - accuracy: 0.7528 - val_loss: 0.6222 - val_accuracy: 0.7404
#
# Epoch 49/100
# 215/215 - 1s - loss: 0.5834 - accuracy: 0.7605 - val_loss: 0.6198 - val_accuracy: 0.7407
#
# legjobb val_acc:
# 0.7419134974479675
# a modell hiperparaméterei:
# 128
# 256
# 128
# 0.339508893545996
# 0.15354426547597855
# 0.22453785882763524
# leakyrelu
# adam
# 256
# Epoch 1/100
# 54/54 - 0s - loss: 1.0472 - accuracy: 0.5526 - val_loss: 0.7777 - val_accuracy: 0.6718
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.8236 - accuracy: 0.6443 - val_loss: 0.7238 - val_accuracy: 0.7012
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.7625 - accuracy: 0.6779 - val_loss: 0.6825 - val_accuracy: 0.7118
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.7298 - accuracy: 0.6930 - val_loss: 0.6668 - val_accuracy: 0.7181
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6931 - accuracy: 0.7030 - val_loss: 0.6501 - val_accuracy: 0.7261
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.6736 - accuracy: 0.7151 - val_loss: 0.6542 - val_accuracy: 0.7268
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.6546 - accuracy: 0.7262 - val_loss: 0.6453 - val_accuracy: 0.7303
#
# Epoch 8/100
# 54/54 - 0s - loss: 0.6439 - accuracy: 0.7275 - val_loss: 0.6338 - val_accuracy: 0.7351
#
# Epoch 9/100
# 54/54 - 0s - loss: 0.6282 - accuracy: 0.7399 - val_loss: 0.6394 - val_accuracy: 0.7322
#
# Epoch 10/100
# 54/54 - 0s - loss: 0.6171 - accuracy: 0.7403 - val_loss: 0.6331 - val_accuracy: 0.7348
#
# Epoch 11/100
# 54/54 - 0s - loss: 0.6122 - accuracy: 0.7445 - val_loss: 0.6317 - val_accuracy: 0.7377
#
# Epoch 12/100
# 54/54 - 0s - loss: 0.6036 - accuracy: 0.7495 - val_loss: 0.6281 - val_accuracy: 0.7371
#
# Epoch 13/100
# 54/54 - 0s - loss: 0.5889 - accuracy: 0.7595 - val_loss: 0.6342 - val_accuracy: 0.7358
#
# Epoch 14/100
# 54/54 - 0s - loss: 0.5763 - accuracy: 0.7586 - val_loss: 0.6211 - val_accuracy: 0.7424
#
# Epoch 15/100
# 54/54 - 0s - loss: 0.5730 - accuracy: 0.7650 - val_loss: 0.6296 - val_accuracy: 0.7411
#
# Epoch 16/100
# 54/54 - 0s - loss: 0.5665 - accuracy: 0.7661 - val_loss: 0.6221 - val_accuracy: 0.7438
#
# Epoch 17/100
# 54/54 - 0s - loss: 0.5537 - accuracy: 0.7707 - val_loss: 0.6194 - val_accuracy: 0.7421
#
# Epoch 18/100
# 54/54 - 0s - loss: 0.5536 - accuracy: 0.7723 - val_loss: 0.6237 - val_accuracy: 0.7443
#
# Epoch 19/100
# 54/54 - 0s - loss: 0.5451 - accuracy: 0.7797 - val_loss: 0.6313 - val_accuracy: 0.7433
#
# Epoch 20/100
# 54/54 - 0s - loss: 0.5283 - accuracy: 0.7827 - val_loss: 0.6262 - val_accuracy: 0.7446
#
# Epoch 21/100
# 54/54 - 0s - loss: 0.5306 - accuracy: 0.7825 - val_loss: 0.6272 - val_accuracy: 0.7453
#
# Epoch 22/100
# 54/54 - 0s - loss: 0.5216 - accuracy: 0.7907 - val_loss: 0.6240 - val_accuracy: 0.7469
#
# Epoch 23/100
# 54/54 - 0s - loss: 0.5171 - accuracy: 0.7912 - val_loss: 0.6262 - val_accuracy: 0.7450
#
# Epoch 24/100
# 54/54 - 0s - loss: 0.5106 - accuracy: 0.7914 - val_loss: 0.6252 - val_accuracy: 0.7458
#
# Epoch 25/100
# 54/54 - 0s - loss: 0.5013 - accuracy: 0.7979 - val_loss: 0.6242 - val_accuracy: 0.7457
#
# legjobb val_acc:
# 0.7468505501747131
# a modell hiperparaméterei:
# 512
# 512
# 512
# 0.14605665645399116
# 0.12243693238510386
# 0.18352268391201432
# swish
# adam
# 128
# ...
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.7161 - accuracy: 0.7014 - val_loss: 0.6799 - val_accuracy: 0.7222
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.7052 - accuracy: 0.7016 - val_loss: 0.6770 - val_accuracy: 0.7213
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.7003 - accuracy: 0.7070 - val_loss: 0.6721 - val_accuracy: 0.7232
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.6902 - accuracy: 0.7132 - val_loss: 0.6695 - val_accuracy: 0.7268
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.6888 - accuracy: 0.7156 - val_loss: 0.6675 - val_accuracy: 0.7297
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.6930 - accuracy: 0.7082 - val_loss: 0.6693 - val_accuracy: 0.7285
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.6840 - accuracy: 0.7184 - val_loss: 0.6629 - val_accuracy: 0.7285
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.6842 - accuracy: 0.7107 - val_loss: 0.6594 - val_accuracy: 0.7300
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.6701 - accuracy: 0.7196 - val_loss: 0.6571 - val_accuracy: 0.7312
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.6787 - accuracy: 0.7184 - val_loss: 0.6568 - val_accuracy: 0.7324
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.6726 - accuracy: 0.7189 - val_loss: 0.6574 - val_accuracy: 0.7331
#
# Epoch 20/100
# 215/215 - 1s - loss: 0.6668 - accuracy: 0.7232 - val_loss: 0.6546 - val_accuracy: 0.7354
#
# Epoch 21/100
# 215/215 - 1s - loss: 0.6673 - accuracy: 0.7216 - val_loss: 0.6532 - val_accuracy: 0.7334
#
# Epoch 22/100
# 215/215 - 1s - loss: 0.6658 - accuracy: 0.7219 - val_loss: 0.6513 - val_accuracy: 0.7356
#
# Epoch 23/100
# 215/215 - 1s - loss: 0.6581 - accuracy: 0.7290 - val_loss: 0.6483 - val_accuracy: 0.7344
#
# Epoch 24/100
# 215/215 - 1s - loss: 0.6622 - accuracy: 0.7246 - val_loss: 0.6492 - val_accuracy: 0.7375
#
# Epoch 25/100
# 215/215 - 1s - loss: 0.6541 - accuracy: 0.7303 - val_loss: 0.6482 - val_accuracy: 0.7331
#
# Epoch 26/100
# 215/215 - 1s - loss: 0.6578 - accuracy: 0.7264 - val_loss: 0.6461 - val_accuracy: 0.7373
#
# Epoch 27/100
# 215/215 - 1s - loss: 0.6505 - accuracy: 0.7305 - val_loss: 0.6468 - val_accuracy: 0.7337
#
# legjobb val_acc:
# 0.737487256526947
# a modell hiperparaméterei:
# 128
# 256
# 128
# 0.4132976357265909
# 0.4571076757263671
# 0.26266116733103045
# relu
# adam
# 128
# Epoch 1/100
# 108/108 - 1s - loss: 1.1209 - accuracy: 0.5027 - val_loss: 0.7859 - val_accuracy: 0.6629
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.8769 - accuracy: 0.6115 - val_loss: 0.7280 - val_accuracy: 0.6948
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.8021 - accuracy: 0.6549 - val_loss: 0.6998 - val_accuracy: 0.7041
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.7520 - accuracy: 0.6795 - val_loss: 0.6799 - val_accuracy: 0.7135
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.7205 - accuracy: 0.6989 - val_loss: 0.6736 - val_accuracy: 0.7152
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.7064 - accuracy: 0.7040 - val_loss: 0.6567 - val_accuracy: 0.7227
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.6784 - accuracy: 0.7171 - val_loss: 0.6510 - val_accuracy: 0.7271
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.6569 - accuracy: 0.7292 - val_loss: 0.6445 - val_accuracy: 0.7288
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.6516 - accuracy: 0.7306 - val_loss: 0.6333 - val_accuracy: 0.7368
#
# Epoch 10/100
# 108/108 - 1s - loss: 0.6391 - accuracy: 0.7392 - val_loss: 0.6281 - val_accuracy: 0.7407
#
# Epoch 11/100
# 108/108 - 1s - loss: 0.6272 - accuracy: 0.7429 - val_loss: 0.6294 - val_accuracy: 0.7388
#
# Epoch 12/100
# 108/108 - 1s - loss: 0.6184 - accuracy: 0.7448 - val_loss: 0.6213 - val_accuracy: 0.7417
#
# Epoch 13/100
# 108/108 - 1s - loss: 0.6101 - accuracy: 0.7502 - val_loss: 0.6171 - val_accuracy: 0.7457
#
# Epoch 14/100
# 108/108 - 1s - loss: 0.6008 - accuracy: 0.7527 - val_loss: 0.6150 - val_accuracy: 0.7465
#
# Epoch 15/100
# 108/108 - 1s - loss: 0.5877 - accuracy: 0.7609 - val_loss: 0.6167 - val_accuracy: 0.7479
#
# Epoch 16/100
# 108/108 - 1s - loss: 0.5828 - accuracy: 0.7618 - val_loss: 0.6143 - val_accuracy: 0.7472
#
# Epoch 17/100
# 108/108 - 1s - loss: 0.5781 - accuracy: 0.7664 - val_loss: 0.6106 - val_accuracy: 0.7486
#
# Epoch 18/100
# 108/108 - 1s - loss: 0.5744 - accuracy: 0.7685 - val_loss: 0.6219 - val_accuracy: 0.7445
#
# Epoch 19/100
# 108/108 - 1s - loss: 0.5552 - accuracy: 0.7772 - val_loss: 0.6098 - val_accuracy: 0.7514
#
# Epoch 20/100
# 108/108 - 1s - loss: 0.5489 - accuracy: 0.7774 - val_loss: 0.6155 - val_accuracy: 0.7504
#
# Epoch 21/100
# 108/108 - 1s - loss: 0.5403 - accuracy: 0.7833 - val_loss: 0.6105 - val_accuracy: 0.7496
#
# Epoch 22/100
# 108/108 - 1s - loss: 0.5262 - accuracy: 0.7877 - val_loss: 0.6158 - val_accuracy: 0.7525
#
# Epoch 23/100
# 108/108 - 1s - loss: 0.5312 - accuracy: 0.7853 - val_loss: 0.6102 - val_accuracy: 0.7501
#
# Epoch 24/100
# 108/108 - 1s - loss: 0.5245 - accuracy: 0.7881 - val_loss: 0.6113 - val_accuracy: 0.7499
#
# Epoch 25/100
# 108/108 - 1s - loss: 0.5143 - accuracy: 0.7951 - val_loss: 0.6103 - val_accuracy: 0.7496
#
# legjobb val_acc:
# 0.7524685263633728
# a modell hiperparaméterei:
# 256
# 512
# 128
# 0.1933165491582815
# 0.24684171080270506
# 0.11502372722498574
# leakyrelu
# rmsprop
# 256
# Epoch 1/100
# 54/54 - 0s - loss: 0.9141 - accuracy: 0.6205 - val_loss: 0.7213 - val_accuracy: 0.6900
#
# Epoch 2/100
# 54/54 - 0s - loss: 0.7343 - accuracy: 0.6876 - val_loss: 0.6909 - val_accuracy: 0.7159
#
# Epoch 3/100
# 54/54 - 0s - loss: 0.6716 - accuracy: 0.7225 - val_loss: 0.6539 - val_accuracy: 0.7351
#
# Epoch 4/100
# 54/54 - 0s - loss: 0.6335 - accuracy: 0.7380 - val_loss: 0.6480 - val_accuracy: 0.7377
#
# Epoch 5/100
# 54/54 - 0s - loss: 0.6014 - accuracy: 0.7540 - val_loss: 0.6472 - val_accuracy: 0.7354
#
# Epoch 6/100
# 54/54 - 0s - loss: 0.5781 - accuracy: 0.7613 - val_loss: 0.6407 - val_accuracy: 0.7354
#
# Epoch 7/100
# 54/54 - 0s - loss: 0.5592 - accuracy: 0.7719 - val_loss: 0.6450 - val_accuracy: 0.7373
#
# legjobb val_acc:
# 0.7376574873924255
# a modell hiperparaméterei:
# 512
# 256
# 128
# 0.39015878190796527
# 0.4144099395389062
# 0.23572691507486981
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9974 - accuracy: 0.5775 - val_loss: 0.7042 - val_accuracy: 0.7002
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7838 - accuracy: 0.6706 - val_loss: 0.6747 - val_accuracy: 0.7152
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.7096 - accuracy: 0.7008 - val_loss: 0.6406 - val_accuracy: 0.7295
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6638 - accuracy: 0.7210 - val_loss: 0.6232 - val_accuracy: 0.7358
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6277 - accuracy: 0.7419 - val_loss: 0.6170 - val_accuracy: 0.7434
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.6060 - accuracy: 0.7511 - val_loss: 0.6251 - val_accuracy: 0.7392
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5746 - accuracy: 0.7623 - val_loss: 0.6086 - val_accuracy: 0.7492
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.5647 - accuracy: 0.7691 - val_loss: 0.6008 - val_accuracy: 0.7538
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.5437 - accuracy: 0.7734 - val_loss: 0.6048 - val_accuracy: 0.7457
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.5253 - accuracy: 0.7829 - val_loss: 0.5943 - val_accuracy: 0.7574
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.5069 - accuracy: 0.7953 - val_loss: 0.6108 - val_accuracy: 0.7528
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.4905 - accuracy: 0.7991 - val_loss: 0.6059 - val_accuracy: 0.7562
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.4784 - accuracy: 0.8094 - val_loss: 0.5957 - val_accuracy: 0.7586
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.4674 - accuracy: 0.8102 - val_loss: 0.6068 - val_accuracy: 0.7526
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.4483 - accuracy: 0.8191 - val_loss: 0.6049 - val_accuracy: 0.7569
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.4391 - accuracy: 0.8231 - val_loss: 0.6066 - val_accuracy: 0.7572
#
# legjobb val_acc:
# 0.758597195148468
# a modell hiperparaméterei:
# 512
# 256
# 512
# 0.28425866930387156
# 0.3446317652107033
# 0.3851666759690027
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.0071 - accuracy: 0.5896 - val_loss: 0.7121 - val_accuracy: 0.6977
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7605 - accuracy: 0.6772 - val_loss: 0.6613 - val_accuracy: 0.7196
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.6752 - accuracy: 0.7177 - val_loss: 0.6373 - val_accuracy: 0.7337
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6359 - accuracy: 0.7357 - val_loss: 0.6331 - val_accuracy: 0.7366
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6001 - accuracy: 0.7513 - val_loss: 0.6091 - val_accuracy: 0.7501
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.5716 - accuracy: 0.7660 - val_loss: 0.6082 - val_accuracy: 0.7474
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5474 - accuracy: 0.7764 - val_loss: 0.6189 - val_accuracy: 0.7506
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.5266 - accuracy: 0.7858 - val_loss: 0.6051 - val_accuracy: 0.7472
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.4991 - accuracy: 0.7945 - val_loss: 0.6030 - val_accuracy: 0.7566
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.4787 - accuracy: 0.8036 - val_loss: 0.6187 - val_accuracy: 0.7497
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.4562 - accuracy: 0.8181 - val_loss: 0.6195 - val_accuracy: 0.7533
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.4367 - accuracy: 0.8254 - val_loss: 0.6298 - val_accuracy: 0.7523
#
# legjobb val_acc:
# 0.7565543055534363
# a modell hiperparaméterei:
# 256
# 128
# 128
# 0.4347490599263676
# 0.48433574868550877
# 0.45128517956279685
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 1.1326 - accuracy: 0.4958 - val_loss: 0.7684 - val_accuracy: 0.6704
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.8669 - accuracy: 0.6192 - val_loss: 0.7225 - val_accuracy: 0.6925
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.7838 - accuracy: 0.6698 - val_loss: 0.6834 - val_accuracy: 0.7155
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.7346 - accuracy: 0.6924 - val_loss: 0.6651 - val_accuracy: 0.7244
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.7065 - accuracy: 0.7070 - val_loss: 0.6506 - val_accuracy: 0.7252
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.6802 - accuracy: 0.7162 - val_loss: 0.6508 - val_accuracy: 0.7264
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.6619 - accuracy: 0.7282 - val_loss: 0.6342 - val_accuracy: 0.7365
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.6487 - accuracy: 0.7351 - val_loss: 0.6267 - val_accuracy: 0.7366
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.6346 - accuracy: 0.7386 - val_loss: 0.6108 - val_accuracy: 0.7450
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.6138 - accuracy: 0.7514 - val_loss: 0.6111 - val_accuracy: 0.7448
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.6061 - accuracy: 0.7499 - val_loss: 0.6078 - val_accuracy: 0.7469
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.5899 - accuracy: 0.7606 - val_loss: 0.6067 - val_accuracy: 0.7475
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.5746 - accuracy: 0.7635 - val_loss: 0.6047 - val_accuracy: 0.7462
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.5683 - accuracy: 0.7718 - val_loss: 0.6010 - val_accuracy: 0.7450
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.5544 - accuracy: 0.7772 - val_loss: 0.6046 - val_accuracy: 0.7484
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.5510 - accuracy: 0.7794 - val_loss: 0.6000 - val_accuracy: 0.7499
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.5394 - accuracy: 0.7833 - val_loss: 0.5965 - val_accuracy: 0.7537
#
# Epoch 18/100
# 215/215 - 1s - loss: 0.5207 - accuracy: 0.7912 - val_loss: 0.6016 - val_accuracy: 0.7475
#
# Epoch 19/100
# 215/215 - 1s - loss: 0.5223 - accuracy: 0.7879 - val_loss: 0.5943 - val_accuracy: 0.7525
#
# Epoch 20/100
# 215/215 - 1s - loss: 0.5115 - accuracy: 0.7934 - val_loss: 0.6049 - val_accuracy: 0.7475
#
# legjobb val_acc:
# 0.7536602020263672
# a modell hiperparaméterei:
# 128
# 256
# 256
# 0.30982508996896807
# 0.07092941603855346
# 0.13617425634150745
# swish
# sgd
# 128
#  98%|█████████▊| 98/100 [27:46<00:36, 18.31s/it, best loss: -0.7671092748641968]WARNING:tensorflow:AutoGraph could not transform <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82e566bc18>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82e566bc18>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82e566bc18>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <bound method keras_fmin_fnct.<locals>.Swish.call of <temp_model.keras_fmin_fnct.<locals>.Swish object at 0x7f82e566bc18>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/100
# 108/108 - 1s - loss: 1.0861 - accuracy: 0.5251 - val_loss: 0.8972 - val_accuracy: 0.6452
#
# Epoch 2/100
# 108/108 - 1s - loss: 0.9237 - accuracy: 0.5984 - val_loss: 0.8074 - val_accuracy: 0.6711
#
# Epoch 3/100
# 108/108 - 1s - loss: 0.8704 - accuracy: 0.6230 - val_loss: 0.7696 - val_accuracy: 0.6791
#
# Epoch 4/100
# 108/108 - 1s - loss: 0.8497 - accuracy: 0.6295 - val_loss: 0.7470 - val_accuracy: 0.6900
#
# Epoch 5/100
# 108/108 - 1s - loss: 0.8274 - accuracy: 0.6437 - val_loss: 0.7366 - val_accuracy: 0.6954
#
# Epoch 6/100
# 108/108 - 1s - loss: 0.8101 - accuracy: 0.6525 - val_loss: 0.7280 - val_accuracy: 0.7043
#
# Epoch 7/100
# 108/108 - 1s - loss: 0.7971 - accuracy: 0.6603 - val_loss: 0.7245 - val_accuracy: 0.7021
#
# Epoch 8/100
# 108/108 - 1s - loss: 0.7923 - accuracy: 0.6626 - val_loss: 0.7252 - val_accuracy: 0.6975
#
# Epoch 9/100
# 108/108 - 1s - loss: 0.7791 - accuracy: 0.6715 - val_loss: 0.7163 - val_accuracy: 0.6997
#
# legjobb val_acc:
# 0.7042900919914246
# a modell hiperparaméterei:
# 512
# 256
# 128
# 0.4547014574766357
# 0.3006644605512727
# 0.2544965268677523
# relu
# adam
# 64
# Epoch 1/100
# 215/215 - 1s - loss: 0.9868 - accuracy: 0.5759 - val_loss: 0.7013 - val_accuracy: 0.6983
#
# Epoch 2/100
# 215/215 - 1s - loss: 0.7681 - accuracy: 0.6679 - val_loss: 0.6673 - val_accuracy: 0.7164
#
# Epoch 3/100
# 215/215 - 1s - loss: 0.6942 - accuracy: 0.7031 - val_loss: 0.6454 - val_accuracy: 0.7285
#
# Epoch 4/100
# 215/215 - 1s - loss: 0.6613 - accuracy: 0.7181 - val_loss: 0.6234 - val_accuracy: 0.7411
#
# Epoch 5/100
# 215/215 - 1s - loss: 0.6373 - accuracy: 0.7337 - val_loss: 0.6151 - val_accuracy: 0.7450
#
# Epoch 6/100
# 215/215 - 1s - loss: 0.6035 - accuracy: 0.7516 - val_loss: 0.6074 - val_accuracy: 0.7462
#
# Epoch 7/100
# 215/215 - 1s - loss: 0.5945 - accuracy: 0.7572 - val_loss: 0.6051 - val_accuracy: 0.7446
#
# Epoch 8/100
# 215/215 - 1s - loss: 0.5740 - accuracy: 0.7616 - val_loss: 0.5965 - val_accuracy: 0.7489
#
# Epoch 9/100
# 215/215 - 1s - loss: 0.5567 - accuracy: 0.7690 - val_loss: 0.5965 - val_accuracy: 0.7550
#
# Epoch 10/100
# 215/215 - 1s - loss: 0.5300 - accuracy: 0.7803 - val_loss: 0.5966 - val_accuracy: 0.7489
#
# Epoch 11/100
# 215/215 - 1s - loss: 0.5292 - accuracy: 0.7821 - val_loss: 0.5930 - val_accuracy: 0.7538
#
# Epoch 12/100
# 215/215 - 1s - loss: 0.5094 - accuracy: 0.7925 - val_loss: 0.5924 - val_accuracy: 0.7555
#
# Epoch 13/100
# 215/215 - 1s - loss: 0.4915 - accuracy: 0.7981 - val_loss: 0.5930 - val_accuracy: 0.7600
#
# Epoch 14/100
# 215/215 - 1s - loss: 0.4852 - accuracy: 0.8038 - val_loss: 0.5924 - val_accuracy: 0.7639
#
# Epoch 15/100
# 215/215 - 1s - loss: 0.4619 - accuracy: 0.8103 - val_loss: 0.6049 - val_accuracy: 0.7571
#
# Epoch 16/100
# 215/215 - 1s - loss: 0.4656 - accuracy: 0.8120 - val_loss: 0.6025 - val_accuracy: 0.7618
#
# Epoch 17/100
# 215/215 - 1s - loss: 0.4565 - accuracy: 0.8127 - val_loss: 0.5941 - val_accuracy: 0.7613
#
# legjobb val_acc:
# 0.7638747096061707
# 100%|██████████| 100/100 [28:14<00:00, 16.94s/it, best loss: -0.7671092748641968]

# %%
x_train, y_train, x_test, y_test = data2()
print("best model evaluation:")
print(best_model.evaluate(x_test, y_test))
print("best hyperparameters:")
print(best_run)
# Out:
# legjobb modell kiértékelése:
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6119 - accuracy: 0.7603
# [0.6119480133056641, 0.7602996230125427]
# legjobb hiperparaméterek:
# {'act': 0, 'dropout_1': 0.4125126321857873, 'dropout_1_1': 0.2548977255951299, 'dropout_1_2': 0.47420624738623013, 'n_batch': 0, 'n_layer1': 2, 'n_layer1_1': 1, 'n_layer1_2': 0, 'optim': 1}

# %%
best_model.save('hyperparam2_best_model.h5')

# %% [markdown]
# The best model of this hyperparamer optimalization giving an accuracy of 76.03%. This model used the GloVe data.
